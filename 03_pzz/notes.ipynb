# %% [markdown]
# # Пример извлечения адресов из комментариев к ПЗЗ

# %% [markdown]
# Параллельно с историей про реконструкцию в Москве обсуждались новые Правила землепользования и застройки (ПЗЗ). Был проведён опрос населения. Более 100 000 комментариев были выложены в открытый доступ в виде огромного pdf-файла http://telegra.ph/PZZ---analitika-proshedshih-slushanij-05-01. Наташей можно извлечь упомянутые адреса и посмотреть в каких районах закон поддерживают, а в каких нет:
# <img src="https://habrastorage.org/web/856/518/44a/85651844a0074f1aa5a25cc14d82c29f.png"/>

# %%
texts = []
with open('comments.txt') as file:
    for line in file:
        line = line.rstrip()
        texts.append(line)

# %%
from natasha import AddressExtractor
from natasha.markup import show_markup, show_json

extractor = AddressExtractor() 

for text in texts:
    matches = extractor(text)
    if matches:
        spans = [_.span for _ in matches]
        show_markup(text, spans)
        facts = [_.fact.as_json for _ in matches]
        show_json(facts)
# Out:
# Желательно побыстрее достроили дом по ул. Живописная д. 21.
#                                       --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 1. Предлагаю вернуть прежние границы природного парка №71 на
# Инженерной улице 2. Предлагаю вернуть прежние основные виды
# ------------------
# разрешенного использования кинотеатру Марс как единственному
# культурно-просветительному объекту района (отменить новый №10322764,
# оставить старый №1037598) 3. По адресу Алтуфьевское шоссе д.51
#                                        -----------------------
# (основной вид разрешенного использования: производственная
# деятельность, склады) размещен МПЗ. Жители требуют незамедлительной
# остановки МПЗ и его вывода из района, как несоответствующего виду
# разрешенного использования (№103320408) В проект ПЗЗ включена карта
# градостроительного зонирования: «Границы зон охраняемого природного
# ландшафта».
# [
#   {
#     "parts": [
#       {
#         "name": "Инженерной",
#         "type": "улица"
#       },
#       {
#         "number": "2"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Алтуфьевское",
#         "type": "шоссе"
#       },
#       {
#         "number": "51",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ТСЖ «Гранатный,6» как представитель собственников жил. дома по
# указанному адресу выражает свое несогласие с показателями застройки
# для земельного участка по адресу: гранатный, вл. 6, стр. 1 (кад. №
# 77:01:0001067:26). Считаем, что реализация строительства отеля по
# указанном адресу и в предельных параметрах ( неразборчиво) ценности
# объекту «Дом Майкова», будет являться прямым нарушением против жителей
#  дома по ул. гранатный. Существенно ухудшит обстановку на нашей улице
# и условия проживания. Просим исключить из ПЗЗ параметры застройки
# участка по адресу г. Москва, Гранатный пер., 6, стр. 1 и отменить ГПЗУ
#                   --------------------------------------
#  №RU77-181000-020710 от 2016 в связи с установлениемпоказателей,
# превышающих ТЭПы ранее существовавшего объекта недвижимости на данном
# участке. участке отсутствуют объекты культурного наследия и выявленные
#  объекты культурного наследия.
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Гранатный",
#         "type": "переулок"
#       },
#       {
#         "number": "6"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# действующий В отношении земельных участков в кадастровыми номерами
# 77:07:00203:67 77:07:0002003:64 77:07:0002003:76 просим учесть
# показатели комплексной типовой застройки суммарной поэтажной площадью
# до 18000 кв.м. строительство реконструкцииподоверенности №7 от
# 14.12.16 выданой Ген.директором Чистовым М.А. здания по адресу: Москва
#                                                                 ------
#  Береговой проезд4/6 стр.3 свидетельство о собственности 77-АР 704078
# --------------------------
# кадастровый номер 77:07:00020034455.
# [
#   {
#     "parts": [
#       {
#         "name": "Москва Береговой",
#         "type": "проезд"
#       },
#       {
#         "number": "4/6"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# В соответствии с генпланом города Москвы от 2025 года а также ППМ
# 793-ПП от 24.12.2012 "Об отраслевой схеме размещение в г. Москве" и
# адресным перечнем размещения гостиниц подлежащих учету при подготовке
# документации по планировке территории на период 2017- 2018
# прохождением в декабре ГЗК прошу включить ТЭП ЗУ с номером
# 77:01:0006017:46 в проект ПЗЗ района Замосворечье77:01:0006017:46
# объекты размещения гостиниц (1004 07). Объекты размещения офисных
# помещений, деловых центров с несколькими функциями (1001 07). Объекты
# размещения коммерческих организаций связанных с проживанием населения
# (1001 08). Объекты размещения коммерческих организаций не связанных с
# проживаием населения (1001 09). Объекты размещения организаций
# розничной торговли продовольственными, не продовольственными группами
# товаров (1004 01). Объекты размещения организаций общественного
# питания (1007 03).Объекты размещения организаций бытового обслуживания
#  (1004 04). Объекты размещения больничных учреждений без специальных
# требований к размещению (1005 01). Объекты размещения ааптек, оптик и
# магазинов медицинских товаров и оборудования, молочных кухонь (1005
# 10). Объекты размещения помещений и технических устройств многоэтажных
#  и подземных гаражей стоянок (3004 09). Объекты размещения помещений и
#  технических устройств, распределительных пунктов, распределительных
# трансформаторных подстанций, центральных тепловых пунков, тепловых
# камер павильонов, газорегуляторных пунктов на газопродах давлением
# менее 1,2 МПА (3004 02). Условно разрешенные виды использования: не
# установлены. Вспомогательные виды: - виды использования,
# технологически связанные с видами использования объектов
# капстроительства в том числе необходимые для обеспечения их
# безопасности. - виды использования необходимые для осблуживания,
# временного проживания, хранения автотранспортных средств пользователей
#  объектов основных видов и иных вспомогательных видов использования.
# Виды использования, необходимые для инженерно-технического и
# транспортного обеспечения объектов основных видов и иных видов
# вспомогательного использования. Максимальный процент застройки 50%.
# Высота застройки 72 м. Плотность застройки 40 тыс. кв.м.Суммарная
# поэтажная площадь объектов в габаритах наружных стен 43 тыс. кв.м.
#                                                                 ---
# Подземная площадь 8 400 кв.м. Кличество м/м 195. Дополнительно
# -------------------
# прилагается письмо №05 от 16.12.2016.
# [
#   {
#     "parts": [
#       {
#         "name": "м. Подземная",
#         "type": "площадь"
#       },
#       {
#         "number": "8"
#       }
#     ]
#   }
# ]
# депутат СД Считаю, что строительство по адресу: ул.Онежская, вл.5
# нецелесообразно, т.к. это точечная застройка, такая же ситуация с
# ул.Авангардная, д.12, ул.Кронштадтский бул., д.47, стр.4 (или 47В) так
# --------------------     -------------------------------
#  же не овечает интересам жителей, однако данный объект возведен без
# законодательного разрешения, но под снос так и не включен. В тоже
# время очень мало соц.объектов. 1.
# [
#   {
#     "parts": [
#       {
#         "name": "Авангардная",
#         "type": "улица"
#       },
#       {
#         "number": "12",
#         "type": "дом"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Кронштадтский",
#         "type": "бульвар"
#       },
#       {
#         "number": "47",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Прекрасная экспозиция. Достройте дом на ул.Живописная,д.21
#                                         ------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Внести в ПЗЗ следующие изменения: для земельного участка
# 77:03:0002015:8269 по адресу: Щелковское ш., 75 указать основные ВРИ:
#                               -----------------
# 4.0.0, 7.2.1, 7.2.3, 3.0.0
# [
#   {
#     "parts": [
#       {
#         "name": "Щелковское",
#         "type": "шоссе"
#       },
#       {
#         "number": "75"
#       }
#     ]
#   }
# ]
# Учесть возможность выделить в отдельную зону участок по адресу проезд
#                                                                -------
# Березовой рощи, дом 2 (детская городская больница.
# ---------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Березовой рощи",
#         "type": "проезд"
#       },
#       {
#         "number": "2",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Требуем в соответствии с действующим законодательством учесть решение
# заседания градостроительной земельной комиссии от 28.05.2015при
# подготовке проекта межевания квартала с кадастровым номером
# 77:02:002002 и номером 77:02 0020021:4902 участок, необходимый для ГСК
#  «Строитель-2 по адресу г. Москва ул. Ак. Королева д.8 к.1 стр.2 и
#                         --------------------------------
# объединить этот участок с нашим участком с кадастровым номером
# 77:02.00200213. Частично участок, необходимый нам для завершения
# строительства гаражного комплекса, был изъят у нашего кооператива
# безосновательно в 2000 году.
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Ак. Королева",
#         "type": "улица"
#       },
#       {
#         "number": "8 к",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 1. По адресу Алтуфьевское шоссе, д.51 –основной вид разрешенного
#              ------------------------
# использования территории: производственная деятельность; склады. По
# данному адресу размещен МПЗ. Жители района требуют незамедлительной
# остановки МПЗ и вывода его с территории района, как несоответствующего
#  виду разрешенного использования. 2. Просим вернуть прежние границы
# природного парка №71 на Инженерной улице. 3. Просим вернуть прежние
# основные виды разрешенного использования кинотеатру «Марс», как
# единственному культурно-просветительному объекту района. По адресу
# Алтуфьевское ш., д. 51 проектом ПЗЗ предусматривается сохранение
# ----------------------
# фактическое использования – индекс «Ф». В проект ПЗЗ включена карта
# градостроительного зонирования: «Границы зон охраняемого природного
# ландшафта».
# [
#   {
#     "parts": [
#       {
#         "name": "Алтуфьевское",
#         "type": "шоссе"
#       },
#       {
#         "number": "51",
#         "type": "дом"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Алтуфьевское",
#         "type": "шоссе"
#       },
#       {
#         "number": "51",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Исключить зону ООПТ с территории арендуемого земельного участка кад. №
#  7707:001:001:2 по адресу: ул. Крылатская, 37.
#                            ------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Крылатская",
#         "type": "улица"
#       },
#       {
#         "number": "37"
#       }
#     ]
#   }
# ]
# Достройка дома по ул. Живописной д. 21
#                   --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописной",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# по адресу Ленинградский проспект вл. 2 снизить этажность и плотность.
# Зем участок находится в зоне регул. Застройки, на границе объед. охр
# зоны. По адресу Ленинградское 1.проспект вл.31 снизить этажность и
# плотность. Зем участок находится в зоне регул. Застройки, на границе
# объед. охр зоны. По адресу Верняя 34 снизить этажность и плотность.
# Зем участок находится в зоне регул. Застройки, на границе объед. охр
# зоны. По адресу ул. Расковой 11а вернуть вид разрешенного
#                 ----------------
# использования для дошкольных учреждений. По адресу 1-я ул. Ямского
#                                                        ------------
# поля 12 вернуть зем. участк вид разрешения использов. для медицинских
# -------
# учреждений. проспект, вл.2, проектом ПЗЗ предусматривается сохранение
# фактическое использования – индекс «Ф»: - в качестве основных видов
# разрешенного использования земельных участков и объектов капитального
# строительства, устанавливаются виды разрешенного использования
# упомянутых земельных участков и объектов капитального строительства,
# сведения о которых содержатся в Едином государственном реестре
# недвижимости; - в качестве предельных параметров разрешенного
# строительства, реконструкции объектов капитального строительства на
# земельных участках в упомянутых зонах устанавливаются параметры
# расположенных на указанных земельных участках объектов капитального
# строительства, сведения о которых 2, 3.
# [
#   {
#     "parts": [
#       {
#         "name": "Расковой",
#         "type": "улица"
#       },
#       {
#         "number": "11а"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Ямского поля",
#         "type": "улица"
#       },
#       {
#         "number": "12"
#       }
#     ]
#   }
# ]
# Определить зону развития по адресу: Дашков пер., вл.7 и ул. Тимура
# Фрунзе, вл.32 (земельные участки с кадастровыми номерами
# №77:01:0005015:3030, №77:01:0005015:3029) для строительства второй
# очереди лечебного центра общей наземной площадью до 3800 кв.м.,
# высотой до 35 м, подземной площадью с машиноместами - до 1300 кв.м, с
# предельной плотностью застройки до 35000 кв.м. на 1 Га территории.
# Определить зону развития по адресу: Новодевичий проезд владение 6 ,
#                                                 --------------------
# строение 2 и Погодинская улица владение 22, строение 3 (земельный
# ------------
# участок кадастровый № 77:01:0005006:1007) для реализации проекта
# медицинского центра, детского сада и жилого многоквартирного дома
# общей площадью до 25000 кв.м., высотой до 47,25 м, с предельной
# плотностью застройки до 25000 кв.м. на 1 га территории с
# обеспеченностью машиноместами и гаражом согласно действующим нормам, с
#  площадью застройки до 60%.
# [
#   {
#     "parts": [
#       {
#         "name": "владение",
#         "type": "проезд"
#       },
#       {
#         "number": "6"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Я против строительства 18 этажного здания на участке с кадастровым №
# 77:06:0007:003:1001 (ул. Профсоюзная, д.128), считаю, что нужно
#                      ----------------------
# установить предельную этажность застройки этогоучастка до 1 этажа
# (территориальная зона №2054149).
# [
#   {
#     "parts": [
#       {
#         "name": "Профсоюзная",
#         "type": "улица"
#       },
#       {
#         "number": "128",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Скорейшее окончание стройки на ул. Живописная д. 21.
#                                --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Участок между домами по улице Ясногорская 7 и Новоясенский пр-т д.13
#                         --------------------- -----------------------
# кор.1. Категорически против застройки. Еинственное место, где можно
# -----
# было отдыхать, гулять пенсионерам и мамам с детьми. Вокруг все
# застроено домами, гаражами, торговыми центрами, которые стоят
# полупустые. На этом участке ужеи роют котлован, забор стоит в 8 метрах
#  от жилого дома по улице Ясногорская д. 7. Есть выписка из БТИ, что
#                    ----------------------
# территория относится у дому № 7 и на ней не имеют право строить.
# [
#   {
#     "parts": [
#       {
#         "name": "Ясногорская",
#         "type": "улица"
#       },
#       {
#         "number": "7 и"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Новоясенский",
#         "type": "проспект"
#       },
#       {
#         "number": "13",
#         "type": "дом"
#       },
#       {
#         "number": "1",
#         "type": "корпус"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Ясногорская",
#         "type": "улица"
#       },
#       {
#         "number": "7",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Предлагаю изменить назначение земельного участка по адресу:
# Б.Галушкина 10/2 и отменить ГПЗУ на него. Прошу использовать данный
# ------------------
# участок для строительства объекта спортивного назначения для детей 2-3
#  этажного. На карте данный объект отмечен «Ф» , а должен стоять №
# ГПЗУ.
# [
#   {
#     "parts": [
#       {
#         "name": "Галушкина",
#         "type": "бульвар"
#       },
#       {
#         "number": "10/2 и"
#       }
#     ]
#   }
# ]
# Просим Вас рассмотреть вопрос снижения этажности до 5-ти этажей на
# объект, расположенный по адресу: Каширское шоссе, д. 80. По ГПЗУ
#                                  ----------------------
# предусмотрено 6 этажей. (район Орехово-Борисово Северное).
# [
#   {
#     "parts": [
#       {
#         "name": "Каширское",
#         "type": "шоссе"
#       },
#       {
#         "number": "80",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# У нас парк «Дубки» и ул. Дубки, 15. Значит, при советской власти там
#                      -------------
# был детский сад, его снесли и хотели построить там дом. Наши жители
# отстояли это место. Теперь там строится детский сад. И у меня вопрос:
# в какие сроки его построят, какая его вместимость и какой вид будет
# этого учреждения? Даны разъяснения в ходе собрания участников
# публичных слушаний.федеральными законами.
# [
#   {
#     "parts": [
#       {
#         "name": "Дубки",
#         "type": "улица"
#       },
#       {
#         "number": "15"
#       }
#     ]
#   }
# ]
# Предлагаю сформировать зону развития по адресу: Новодевичий проезд
#                                                             -------
# владение 6 , строение 2 и Погодинская улица владение 22, строение 3
# -------------------------
# (земельный учаток кадастровый № 77:01:0005006:1007) для размещения
# медицинского центра, детского сада и жилого многоквартирного дома
# общей наземной площадью до 25000 кв.м., высотой до 47,25 м, с
# предельной плотностью застройки до 25000 кв.м. на 1 га территории с
# обеспечением машиноместами и гаражом, согласно положенным нормам с
# площадью застройки земельного участка до 60%. Определить зону развития
#  по адресу: Дашков пер., вл.7 и ул. Тимура Фрунзе, вл.32 (земельные
# участки с кадастровыми номерами №77:01:0005015:3030,
# №77:01:0005015:3029) для строительства мед центра общей наземной
# площадью до 3800кв.м., высотой до 35 м, подземной парковкой - до 1300
# кв.м, с предельной плотностью застройки до 35000 кв.м. на 1 Га
# территории.
# [
#   {
#     "parts": [
#       {
#         "name": "владение",
#         "type": "проезд"
#       },
#       {
#         "number": "6"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Прошу достроить дом на ул.Живописная, 21 и благоустроить набережную
#                        -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21 и"
#       }
#     ]
#   }
# ]
# Как можно быстрее достроить дом по Живописной ул., д. 21, и
#                                    ---------------------
# облагородить набережную.
# [
#   {
#     "parts": [
#       {
#         "name": "Живописной",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Достроить скорей дом на ул. Живописной 21 и прилежащей к ней
#                         -------------------
# набережной благоустроить
# [
#   {
#     "parts": [
#       {
#         "name": "Живописной",
#         "type": "улица"
#       },
#       {
#         "number": "21 и"
#       }
#     ]
#   }
# ]
# , жительница района Зябликово. Около дома по Ореховому бульвару, 67,
#                                              ----------------------
# рядом с магазином «Магнолия» затеяли какое-то строительство. Я не
# особо слежу за ситуацией, нет времени, но соседи возмущаются, что
# опять не посоветовались с жителями. Что это за объект? Нам магазин не
# нужен. Даны разъяснения в ходе собрания участников публичных слушаний.
#  Кунаева О.М.: Действительно ранее было принято решение по этому
# адресу о размещении торгового объекта, но поскольку от жителей района
# в большом количестве поступали возражения, но на городской комиссии
# было принято решение выпустить ГПЗУ с нулевыми показателями. На данном
#  участке не будет вестись строительство, только благоустройство. Ильин
#  А.Ю.: Это как раз тот случай, когда мы отразили выданный ГПЗУ.
# Присутствует территориальная зона, указывающая на выданный ГПЗУ, но
# если посмотреть на параметры этой территориальной зоны, вы увидите,
# что плотность, высота и застроенность установлены с нулевыми
# параметрами. Это обозначает, что будет благоустройство территории.
# Зверев С.И.: Александр Юрьевич, скажите попроще, что ничего там не
# будет, а с благоустройством разберемся.
# [
#   {
#     "parts": [
#       {
#         "name": "Ореховому",
#         "type": "бульвар"
#       },
#       {
#         "number": "67"
#       }
#     ]
#   }
# ]
# (ФИО не разборчиво) АО "МПСИ" на праве собственности принадлежит
# здание по адресу: г. Москва,ул. Тимура Фрунзе д.10 (кад.№
#                   --------------------------------
# 77:01::0005015:3069) представлен в аренду(договор аренды №М-01-
# 048746). На указанном зем. участке планируется строительство жилого
# дома, суммарной наземной 5189,8кв.м. Прощу вас учесть в ПЗЗ выделив
# обособленную зону и предусмотрев в качестве основного вида разрешить
# испоп. код 2.6.0 (земная застройка выше 9 эт.) и установив
# максимальное значение плотности застройки - 35тыс. кв.м./га, высота -
# 28м,застроенность-70%.
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Тимура Фрунзе",
#         "type": "улица"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Предлагаю определить зону развития по адресу: Новодевичий проезд,
# владение 6, строение 2 и Погодинская улица, владение22 строение 3
# (земельный кадастровый номер 77:01:0005006:1007) и для строительства
# медицинского центра, детского центра и жилого многоквартирного дома,
# общей наземной площадью до 25000 кв.м высотой до 47,25 м с предельной
# плотностью застройки до 25000 кв.м на 1 га территории с обеспечением
# машиномест и гаражом согласно действующим нормативам с площадью
# застройки земельного участка до 60%. Голосую за зону развития по
# адресу: Дашков переулок владение 7 и ул. Тимура Фрунзе владение 32
#                ---------------------
# (земельные участки с кадастровыми номерами (земельные участки с
# кадастровыми номерами № 77:01:0005015:3030 и № 77:01:00050150:3029)
# для строительства объекта медицинского назначения общей наземной
# площадью до 38000 кв.м высотой до 35 м, подземной площадью до 13000
# кв.м с предельной плотностью застройки до 35000 кв.м на 1 га
# территории.
# [
#   {
#     "parts": [
#       {
#         "name": "владение",
#         "type": "переулок"
#       },
#       {
#         "number": "7 и"
#       }
#     ]
#   }
# ]
# Побыстрее завершить строительство на ул.Живописная, 21
#                                      -----------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21"
#       }
#     ]
#   }
# ]
# Я Журавлева Лариса Николаевна. Проживающая по адресу: Москва,
#                                                       --------
# Вспольный пер., д. 10, кв. 27, ознакомившись с экспозицией ПЗЗ по ЦАО,
# -----------------------------
#  сообщаю следующее. В средствах массовой информации делаются громкие
# заявления на государственном уровне о необходимости охраны и
# воссоздания памятников истории и культуры. Однако, вместо дома
# Майкова, который ранее располагался на земельном участке по адресу: г.
#  Москва.Гранатный пер., вл. 6, стр. 1, к строительству предлагается
# гостиница. При этом, согласно материалов ПЗЗ еще одним из видов
# разрешенного использования земельного участка является обслуживание
# автотранспорта. В принципе, я не против строительства, но считаю что
# параметры предлагаемого строительства объекта. указанные в ГПЗУ
# №RU77-181000- 020710 (предельная высота здания - 9.4 метра; суммарная
# поэтажная площадь объекта в габаритах наружных стен - 875 кв.м.,
# максимальный процент застройки - 25000 кв.м/Га) явно завышена по
# параметрам такого ГПЗУ в сторону уменьшения, а именно: уменьшить
# предельную высоту здания ф 7.70 кв.м., а также уменьшить общую площадь
#  объекта до 570.6 кв.м., как это было ранее предусмотрено в ГПЗУ №
# RU77181000-002827, утвержденном приказом Москомархитектуры от
# 31.01.2012 № 145. Москве от 07.04.2016 г. № 72/2/1424-МС и
# утвержденному в установленном порядке. В соответствии с информацией,
# представленной Департаментом культурного наследия города Москвы, в
# настоящее время на указанном земельном участке отсутствуют объекты
# культурного наследия и выявленные объекты культурного наследия.
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Вспольный",
#         "type": "переулок"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       },
#       {
#         "number": "27",
#         "type": "квартира"
#       }
#     ]
#   }
# ]
# По Инженерной ул. 1, по территориальной зоне № 10322764 не
# -------------------
# целесообразно менять основные виды разрешенного использования в связи
# с отсутствием в районе культурных объектов. Оставить основные виды
# разрешенного использования по территориальной зоне 1037598 по
# инженерной ул. вл.1. Просьба увеличить границы природного комплекса до
#  границ существующего народного парка (до Инженерной улицы).
# [
#   {
#     "parts": [
#       {
#         "name": "По Инженерной",
#         "type": "улица"
#       },
#       {
#         "number": "1"
#       }
#     ]
#   }
# ]
# Улучшить состояние города, СЗО р-на по Живописной ул., д. 21.
#                                        ---------------------
# замечания и предложения, относящиеся к предмету публичных слушаний по
# проекту ПЗЗ, отсутствуют
# [
#   {
#     "parts": [
#       {
#         "name": "Живописной",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Хочу выразить благодарность за внесение в проект на территории районов
#  Новокосино и Косино-Ухтомское культурно-досуговых центров, а также
# спортивных объектов, которых так не хватало ранее. Однако, прошу
# принять во внимание торговый объект по адресу: ул. Большая Косинская,
#                                                -----------------------
# 27а, данный объект находится на территории а/м дороги. Из-за его
# ---
# расположения при повороте на круговое движение в сторону ул. Черное
# озеро полностью перекрыта видимость встречного потока. В связи с этим
# прошу соответствующие органы рассмотреть вопрос о сносе данного
# объекта.
# [
#   {
#     "parts": [
#       {
#         "name": "Большая Косинская",
#         "type": "улица"
#       },
#       {
#         "number": "27а"
#       }
#     ]
#   }
# ]
# 1.Предлагаю определить зону развития по адресу: Дашков переулок
#                                                        ---------
# владение 7 и ул. Тимура Фрунзе владение 32 (земельные участки с
# ------------
# кадастровыми номерами (земельные участки с кадастровыми номерами №
# 77:01:0005015:3030 и № 77:01:00050150:3029) для строительства объекта
# медицинского назначения общей наземной площадью до 38000 кв.м высотой
# до 35 м, подземной площадью до 13000 кв.м с предельной плотностью
# застройки до 35000 кв.м на 1 га территори. 2. Предлагаю установить
# зону развития по адресу: Новодевичий проезд, владение 6, строение 2 и
# Погодинская улица, владение 22 строение 3 (земельный кадастровый номер
#  77:01:0005006:1007) и для строительства медицинского центра, детского
#  центра и жилого многоквартирного дома, общей наземной площадью до
# 25000 кв.м высотой до 47,25 м с предельной плотностью застройки до
# 25000 кв.м на 1 га территории с обеспечением машиномест и гаражом
# согласно действующим нормативам с площадью застройки земельного
# участка до 60%.
# [
#   {
#     "parts": [
#       {
#         "name": "владение",
#         "type": "переулок"
#       },
#       {
#         "number": "7 и"
#       }
#     ]
#   }
# ]
# Вывести зону ООПТ с территории арендуемого земельного участка кад. №
# 7707:001:001:2 по адресу: ул. Крылатская, 37.
#                           ------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Крылатская",
#         "type": "улица"
#       },
#       {
#         "number": "37"
#       }
#     ]
#   }
# ]
# 1) 2-й Амбулаторный 9- многократно обещали жителям, включая Мэра
# построить ФОК – просим выполнить обещания и изменить вид назначения
# технопарк. 2) Часовая 4 – обещали построить поликлинику 3) Часовая 23
# – исключить строительство гаража, который ранее отклонял СД (рядом с
# жилым домом) 4) Ленинградский пр-т 54-56 – исключить строительство
#                 ------------------------
# торгового комплекса 5) Осуществление строительства квартала 18Б –
# обещали построить дорогу, однако на ПЗЗ нет данной дороги 6) К-тр Баку
#  просим оставить строительство в существующих параметрах культурно-
# досуговый центр в кинотеатре 7) Часовая 30 – каков объект назначения,
# назначена коммерческая организация 8) 1-й Аэропортовский, вл. 5 –
# сменить участки на учебно-воспитательные 9) Не учтено назначение
# заброшенной территории от Головановского сквера до 2-й Балтийский
#                                                    ---------------
# пер., 3 (территория между заборами д/сада и жилого дома Часовая 19)
# -------
# 10) Обустроить и осветить волейбольную площадку (существующую) за 2-й
#                                                                   ----
# Балтийский пер., д. 3 11) Ленингр. 48 – просим снести и построить
# ---------------------
# новую школу 12) Просим оставить д/сад на К.Симонова, 3 13)
# Ленинградский пр-кт 44 незаконно изменено назначение технического
# ----------------------
# здания и построено коммерческого здание – просим не
# узаканивать!Рекомендовать направить предложение об отмене ГПЗУ в МКА.
# 5. Градостроительные регламенты, устанавливаемые ПЗЗ, не
# распространяются на земельные участки, предназначенные для размещения
# и/или занятые линейными объектами. В соответствии с ч.7 ст.36
# Градостроительного кодекса РФ использование земельных участков, на
# которые действие градостроительных регламентов не распространяется или
#  для которых градостроительные регламенты не устанавливаются,
# определяется уполномоченными федеральными органами исполнительной
# власти, уполномоченными органами исполнительной власти субъектов
# Российской Федерации или уполномоченными органами местного
# самоуправления в соответствии с федеральными законами. 6.дошкольного,
# начального и среднего общего образования (детские ясли, детские сады,
# школы, лицеи, гимназии, художественные, музыкальные школы,
# образовательные кружки и иные организации, осуществляющие деятельность
#  по воспитанию, образованию и просвещению). 12.
# [
#   {
#     "parts": [
#       {
#         "name": "Ленинградский",
#         "type": "проспект"
#       },
#       {
#         "number": "54-56"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "2-й Балтийский",
#         "type": "переулок"
#       },
#       {
#         "number": "3"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "2-й Балтийский",
#         "type": "переулок"
#       },
#       {
#         "number": "3",
#         "type": "дом"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Ленинградский",
#         "type": "проспект"
#       },
#       {
#         "number": "44"
#       }
#     ]
#   }
# ]
# Проект поддерживаю. Бассейн ул. Заречье, 9
#                             --------------
# [
#   {
#     "parts": [
#       {
#         "name": "Заречье",
#         "type": "улица"
#       },
#       {
#         "number": "9"
#       }
#     ]
#   }
# ]
# Исключить зону ООПТ из площади арендуемого земельн. участка
# кад.№77:07:0001001:2 (площадь уч.11916 кв.м.) по адресу: Москва, ул.
#                                                          ------------
# Крылатская д.37
# ---------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Крылатская",
#         "type": "улица"
#       },
#       {
#         "number": "37",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Я против строительства 18 этажного здания на участке по ул.
#                                                         ----
# Профсоюзная, 128А, т.к. это строительство ухудшит жизнь проживающих в
# -----------------
# этом районе.
# [
#   {
#     "parts": [
#       {
#         "name": "Профсоюзная",
#         "type": "улица"
#       },
#       {
#         "number": "128А"
#       }
#     ]
#   }
# ]
# Участок №2036329 (Цветной б-р, 15) многократно предлагался жителями
#                   ---------------
# для включения в программу «Народный парк». Предложения неоднократно
# направлялись в управу Тверского района и в префектуру ЦАО. Жителям был
#  предложен для рассмотрения проект благоустройства, разработанный в
# 2016 году «Мэгли Проект», по которому направлены замечания по
# благоустройству и озеленению. На участке жителями был разбит плодовый
# сад, в наст. время более 86 саженцев плодовых культур уничтожено в
# ходе незаконной подготовки площадки к работам по благоустройству.
# Требуем установить нулевые параметры высотности (показатели застройки)
#  на данном участке ПЗЗ для развития территории с учетом создания
# народного парка. Отменить все ранее существующие незаконные
# предложения по застройке, которые противоречат требованиям жителей,
# согласованным с руководством района. Отменить ГПЗУ!
# [
#   {
#     "parts": [
#       {
#         "name": "Цветной",
#         "type": "бульвар"
#       },
#       {
#         "number": "15"
#       }
#     ]
#   }
# ]
# Очень хотелось бы, что бы скорее была внесена ясность о сносе нашего
# дома по ул. Народного Ополчения д. 9к.3. Коммуналку нужно сносить,
#         -----------------------------
# скорей бы это произошло. С проектом согласна.
# [
#   {
#     "parts": [
#       {
#         "name": "Народного Ополчения",
#         "type": "улица"
#       },
#       {
#         "number": "9к",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 1) Я против проекта, т.к. в данном проекте исключен детский сад,
# который регламентирован Распоряжением Правительства Москвы от
# 16.09.2004 №1848-РП и от 01.09.2006 №1717-РП и утвержденным проектом
# застройки многофункционального жилого комплекса с социальными
# объектами, которые этим ПЗЗ исключены. Это форменное безобразие,
# превышение полномочий. Требую включить строительство соц. объекта в
# этот план застройки. Адрес соц. объекта: Высоковольтный пр-д, вл 1
# (посреди жилого комплекса). 2) На представленном плане указано, что
# башни по адресу: Высоковольтный пр-д, д. 1 стр. 32, 33,34, остаются в
#                  ---------------------------------
# существующем виде, я выступаю против этого проекта, прошу это учесть в
#  следующем варианте правил землепользования и застройки. В
# представленном ГПЗУ RU77-175000-008894 не указана этажность здания,
# объект возведен без разрешения на стр-во в 2016 году. 3) Не совсем
# понятна ситуация с представленными сведениями по санитарно защитными
# зонами промышленных предприятий, представлена неактуальная информация
# в части территории района Отрадное. 1)санитарная классификация
# предприятий и сооружений и иных объектов" (новая редакция утв.
# постановлением Главного государственного санитарного врача РФ от
# 25.09.2007г. №74 с изм. и доп. №1,2,3,4) отображены обобщенной
# границей. Объекты, разработавшие проекты организации санитарно-
# защитной зоны, отображены с их расчетными или установленными границами
#  СЗЗ, утвержденными в установленном порядке и имеющими соответствующие
#  санитарно-эпидемиологические заключения Федеральной службы по надзору
#  в сфере защиты прав потребителей и благополучия человека.
# [
#   {
#     "parts": [
#       {
#         "name": "Высоковольтный",
#         "type": "проезд"
#       },
#       {
#         "number": "1",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Проект реконструкции «Байконура» отклонить, т.к. он не в интересах
# жителей района Отрадное. Замечания к правилам землепользования и
# застройки, «реконструкции» Байконура прилагаются на 12 л. как
# приложение к протоколу № 5 от 16.12.2016 г. заседания Совета дома ул.
# Северный б-р 2 района Отрадное. Приложение к Протоколу № 5 от
# --------------
# 16.12.2016 г. заседания Совета дома, 127490, г. Москва, ул. Северный
#                                      --------------------------------
# бульвар, дом 2, района Отрадное Замечания к: 1. Правилам
# --------------
# землепользования и застройки 2. «Реконструкции» к/т «Байконур»
# Попробуем разобраться по порядку, что будет означать для нас, жителей
# Отрадного, так называемая «реконструкция» к/т «Байконур». Начнем с
# самого понятия, что есть реконструкция с точки зрения технических
# строительных определений. 1. Наряду с капитальным ремонтом одним из
# видов восстановления объектов капитального строительства является
# реконструкция, в широком смысле слова означающая коренное
# переустройство; перестройку по новым принципам; восстановление чего-
# либо по сохранившимся остаткам или описаниям. По большому счету,
# реконструкция — это не только и не столько ремонт здания, при котором
# либо полностью сохраняется фасад (а внутренние перекрытия, стены
# существенно изменяются), либо даже внешний антураж здания претерпевает
#  существенные метаморфозы. Реконструкция в большей степени
# представляет собой фактическую перестройку здания. В п. 14 ст. 1 ГрК
#                                                    -------
# РФ под реконструкцией понимается изменение параметров объектов
# капитального строительства, их частей (высоты, количества этажей
# (этажность), площади, показателей производственной мощности, объема) и
#  качества инженерно-технического обеспечения. Законодатель в данной
# статье избрал смешанный путь: закрепил в ст. 1 общие черты понятия
# «реконструкция», а более глубокое содержание данного термина раскрыл в
#  последующих нормах ГрК РФ. Учитывая, что круг объектов недвижимости,
# подлежащих реконструкции, достаточно широк, реконструкция объектов
# капитального строительства представляет собой комплекс строительных
# работ и организационно-технических мероприятий, связанных с изменением
#  основных технико- экономических показателей объекта капитального
# строительства (количества и площади помещений, строительного объема и
# общей площади здания, вместимости или пропускной способности или его
# назначения) в целях улучшения качества обслуживания, увеличения объема
#  услуг. Заметьте: в целях улучшения качества обслуживания, увеличения
# объема услуг, то есть реконструкция не предусматривает изменения
# целевого назначения нашего кинотеатра, он может перестраиваться,
# добавляться кинозалы, даже надстраиваться, но он должен остаться
# кинотеатром «Байконур»! Как правило, реконструкция здания
# предусматривает проведение следующих работ: полную или частичную
# реорганизацию объекта с изменением габаритных размеров и технических
# характеристик; проведение дополнительных строительных работ
# (надстройка, пристройка);реконструкция или полная замена всех
# инженерных систем и коммуникаций; разборка и усиление несущих
# конструкций, возможно переоборудование чердачных помещений под
# мансарду. В процессе реконструкции здание из исходных элементов
# сохраняет лишь несущие конструкции — стены, перекрытия, лестницы.
# Меняется все, что только возможно заменить — половое покрытие,
# перегородки, потолки, коммуникации. И если после реконструкции снаружи
#  здание еще можно узнать, то внутренние помещения обычно претерпевают
# значительные изменения. При этом, прежде чем приступить к этому
# созидательному процессу, пересматриваются существующие планировки,
# проводится ревизия расположения коммуникаций, а также модернизация
# инженерного оборудования зданий. Лишь после того, как были учтены все
# требования к новому облику и внутреннему строению здания, можно
# приступать к проектированию помещений, которые полностью бы отвечали
# современным демографическим и дизайнерским требованиям. Понятие
# «реконструкция» важно отличать от понятия «новое строительство»,
# поскольку допущение смешения этих понятий на практике может привести к
#  конфликтным ситуациям, разрешаемым в судебном порядке — в интернете
# можно посмотреть, например, Постановление Федерального арбитражного
# суда Северо-Западного округа от 05.08.2005 N А56-49972/04. Господа
# чиновники намеренно перепутали понятие реконструкция и новое
# строительство. Согласно инструктивному письму Главной инспекции
# Госархстройнадзора Российской Федерации от 28 апреля 1994 года N
# 18-14/63 [О правильном толковании терминов "новое строительство",
# "капитальный ремонт", "реконструкция", "расширение"]. Цитируем:
# «Реконструкция здания - комплекс строительных работ и организационно-
# строительных мероприятий, связанных с основными технико-экономическими
#  показателями (количеством и качеством квартир, строительного объема и
#  общей площади здания, вместимости, пропускной способности и т.д.) или
#  его назначения, в целях улучшения условий проживания, качества
# обслуживания увеличения объема услуг. При реконструкции зданий помимо
# работ, выполняемых при капитальном ремонте, могут осуществляться:
# изменение планировки помещений, возведение надстроек, встроек,
# пристроек, а при наличии необходимых оснований, их частичная разборка;
#  повышение уровня инженерного оборудования, включая реконструкцию
# инженерных путей (кроме магистральных); улучшение архитектурной
# выразительности здания. При реконструкции объектов коммунального и
# социальнокультурного назначения может предусматриваться расширение
# существующих и строительство новых зданий и сооружений подсобного и
# обслуживающего назначения»... «К новому строительству относятся также
# строительство на новой площадке предприятий такой же или большей
# мощности взамен ликвидируемого». Кинотеатр «Байконур» хотят снести и
# построить новое здание, имеющее уже другое назначение. Вопрос: Почему
# нас, жителей района, власти пытаются ввести в заблуждение, меняя
# понятие «реконструкция» и «новое строительство»? 2. Отсюда вытекает
# другое интересное наблюдение. В газете «Звездный бульвар» №46 за
# декабрь 2016 года на 4 странице размещена статья с крупным заголовком
# «Москва простится с точечным строительством» и «Документ делает
# невозможным уплотнение микрорайонов». Новое строительство здания на
# месте к/т «Байконур» это фактически новое здание, и это никак иначе
# как точечной застройкой не назовешь! Габариты нового здания в полтора
# раза больше габаритов старого, а это уже точно уплотнение нашего
# микрорайона! Вопрос: Почему в газете пишут о том, что «Москва
# простится с точечным строительством», а на деле это продолжается с
# уплотнением нашего микрорайона? 3. Если мы заглянем в Толково-
# словообразовательный словарь, то увидим: РЕКОНСТРУКЦИЯ . 1. Коренное
# переустройство, переоборудование чего-л. // Изменение принципов
# организации чего-л. 2. Воссоздание, восстановление чего-л. по
# сохранившимся остаткам или описаниям. Напрашивается вывод, который
# даже по своей логике правильный. Реконструкция - это воссоздание
# старого объекта из новых материалов без изменения его
# потребительскиххарактеристик в части размеров площадей, этажности,
# планировки и пр. В противном случае появляется новый объект
# недвижимости. Трудно согласиться, с пытающимися протащить под видом
# реконструкции чиновниками с тем, что если на месте барака построить
# небоскреб с соблюдением периметра барака, то это будет являться
# реконструкцией барака, а не созданием нового объекта. Кроме того, если
#  толковать ст.1 ГСК через привязку к земле, то мы получим и
# возможность пересмотра границ земельного участка необходимого и
# достаточного для обслуживания "реконструированного" с увеличением
# этажности здания, а это уже точно новый объект. 4. Сам проект
# «реконструкции» к/т «Отрадного» до недавнего времени входил в так
# называемый опальный проект «ТПУ Отрадное». Строительство «ТПУ
# Отрадное», благодаря стараниям простых жителей Отрадного был
# благополучно отменен. Но власти не хотят останавливаться, и решили
# зайти с другой стороны, протаскивая «реконструкцию» к/т «Отрадного»,
# которая при начале реализации потянет за собой разрушение существующих
#  зданий и строений. 5. Кинотеатр «Байконур» был построен в 1983 году.
# Многие москвичи рассказывают, что для них «Байконур» - это островок
# детства, наполненный воспоминании о воскресных походах в кино с
# родителями и школьными приятелями. Реконструкция к/т Байконур
# происходила в 2001 году и 2014 году, что было совсем недавно. Вопрос:
# Зачем нам еще одна «реконструкция», создающая неудобства для всех
# жителей на 2 года как минимум, если реконструкция была совсем недавно?
#  6. Далее, взглянув на территориальную зону №17518671 книги 4
# «Территориальная часть правил землепользования и застройки Северо-
# Восточного административного округа» мы видим, что согласно данным ГУП
#  МосгорБТИ общая площадь к/т «Байконур» 7886,7 кв. м. Суммарная
# площадь нового объекта в габаритах наружных стен уже 11210 кв. м, что
# практически в полтора раза больше существующих сейчас габаритов здания
#  к/т «Байконур». Это еще раз подтверждает то, что будет новое
# строительство, ведь при реконструкции здание из исходных элементов
# сохраняет несущие конструкции - стены, перекрытия, лестницы в своих
# габаритах. Еще раз повторяем цитату из инструктивного письма Главной
# инспекции Госархстройнадзора Российской Федерации от 28 апреля 1994
# года N 18-14/63 [О правильном толковании терминов "новое
# строительство", "капитальный ремонт", "реконструкция", "расширение"]:
# При реконструкции объектов коммунального и социально- культурного
# назначения может предусматриваться расширение существующих и
# строительство новых зданий и сооружений подсобного и обслуживающего
# назначения». То есть основное здание в своих габаритах остается, а к
# нему могут пристраиваться новые здания и сооружения подсобного и
# обслуживающего назначения. В нашем же случае резко увеличивается в
# полтора раза единая площадь нового здания. Это очевидное новое
# точечное строительство. Вопрос: Почему власти города и на основании,
# каких нормативов допускают резкое увеличение в полтора раза габаритов
# одного единого здания, если это реконструкция? 7. При рассмотрении
# «Карты территориального зонирования» мы видим, что территориальная
# зона №17518671 не содержит в соответствии с ч. 7 ст. 38 Закона о
# кадастре границ координаты поворотных точек, то есть это фактически
# рисунок от руки, не могущий служить документом. При строительстве
# легко можно увеличить пятно застройки и габариты нового здания!
# Вопрос: Почему на «Карте территориального зонирования» нет точных
# координат места посадки территориальной зоны №17518671, иначе
# проектируемого здания? Рассмотрев все территориальные зоны в книгах,
# мы видим, что таких сведений нет нигде. Вопрос: Почему точных
# координат проектируемых зданий и сооружений нет нигде в этих книгах?
# 8. Взглянув на «рисунок» «Карты территориального зонирования» мы
# видим, что территориальная зона N917518671 нарисована в границах общей
#  площади существующего к/т « Байконур» 7886,7 кв. м. Суммарная площадь
#  нового объекта в габаритах наружных стен уже 11210 кв. м, что
# практически в полтора раза больше существующих сейчас габаритов здания
#  к/т «Байконур». Этот факт на «Карте территориального зонирования» не
# отражен. Вопрос: Почему власти вводят жителей в заблуждение, не
# отражая истинных габаритовтерриториальной зоны N917518671? 9. Далее,
# взглянув на пункт 421 территориальной зоны №17518671 книги 4
# «Территориальная часть правил землепользования и застройки Северо-
# Восточного административного округа» мы видим, что в данных таблицы
# отсутствуют: - карты высотности, - коэффициент плотности застройки, -
# коэффициент застройки, - предельно допустимый строительный объем
# зданий и сооружений по отношению к площади отведенного участка, -
# число полных этажей, - допустимая высота зданий и сооружений в этой
# зоне, -данные об облике поселения, - историческая среда, - ландшафтные
#  данные местности, - максимальный процент застройки прилегающей
# ...
#                      ------------------------
# строительства рядом с ООПТ "Сад имени Травникова". Максимум
# восстановить ресторан на прежнем месте и в прежнем здании. Сохранить
# публичные слушания!!! 1.
# [
#   {
#     "parts": [
#       {
#         "name": "Комсомольский",
#         "type": "проспект"
#       },
#       {
#         "number": "1"
#       }
#     ]
#   }
# ]
# Прошу учесть замечания, данные консультанту, по объекту пристройки к
# Детской городской поликлинике по адресу: ул. Декабристов, д.39.
#                                          ---------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Декабристов",
#         "type": "улица"
#       },
#       {
#         "number": "39",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Достроить дом по ул.Живописной, д.21. Благоустроить набережную и
#                  -------------------
# посадить побольше деревьев.
# [
#   {
#     "parts": [
#       {
#         "name": "Живописной",
#         "type": "улица"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Полное несогласие с проектом ТПУ в районе Косино-Ухтомский по ул.
# Дмитриевского. Проектом предусмотрено строительство 2-х многоэтажных
# домов в непосредственной близости к природоохранной зоне, рядом с
# выходом из метро и планируемой автостоянке ТПУ, рядом с дорожным
# интенсивным движением. Предлагаю: 1) запретить строительство 2-х
# многоэтажных домов 2) на выходе из ст. метро ул. Дмитриевского не
# строить здания, а обустроить сквер 3) перенести строительство ТПУ
# западнее ул. Салтыковская, где нет жилых домов 4) Автостоянки сделать
# вдоль Косинского шоссе 1-4.
#       --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Косинского",
#         "type": "шоссе"
#       },
#       {
#         "number": "1-4"
#       }
#     ]
#   }
# ]
# С проектом Правил землепользования и застройки СВАО г. Москвы в целом
# согласен. Прошу внести следующие изменения в части земельных участков
# в районе Лианозово: 1). по земельному участку с кадастровым номером
# 77:02:0003001:1 установить следующие виды разрешенного использования:
# 2.6 — многоэтажная жилая застройка (высотная застройка), 2.7. —
# обслуживание жилой застройки, 3.5 — образование и просвещение,
# установив предельную плотность застройки 39 тыс. кв.м./га, предельную
# высотность застройки - 74 м, предельную застроенность - 29%; а также
# вид разрешенного использования: 4.0 — предпринимательство, установив
# предельную плотность застройки 17 тыс. кв.м./га, предельную высотность
#  застройки - 23 м, а также вид разрешенного использования: 4.9 —
# обслуживание автотранспорта, установив предельную плотность застройки
# 48 тыс. кв.м./га‚ предельную высотность застройки — 26 м. предельную
# 1).застроенность участка 59%‚ и вид разрешенного использования: 12,0 —
#  общее пользование территории, по земельному участку с кадастровым
# номером 77:02:0003002:2 установить следующие виды разрешенного
# использования: 2.6 — многоэтажная жилая застройка (высотная
# застройка), 2.7. — обслуживание жилой застройки, 3.5 — образование и
# просвещение, 4.9 — обслуживание автотранспорта, установив предельную
# плотность застройки 57 тыс. кв.м./га, предельную высотность застройки
# - 74 м, предельную застроенность - 41%; а также вид разрешенного
# использования: 4.0 — предпринимательство, установив предельную
# плотность застройки 17 тыс. кв.м./га, предельную высотность застройки
# - 23 м, вид разрешенного использования: 12.0 — общее пользование
# территории, по земельному участку с кадастровым номером
# 77:02:0003002:3330 установить следующие виды разрешенного
# использования: 2.6 — многоэтажная жилая застройка (высотная
# застройка), 2.7. — обслуживание жилой застройки, 3.5 — образование и
# просвещение, установив предельную плотность застройки 39 тыс.
# кв.м./га‚ предельную высотность застройки - 74 м, предельную
# застроенность - 29%; а также вид разрешенного использования: 4.0 —
# предпринимательство, установив предельную плотность застройки 17 тыс.
# кв.м./га, предельную высотность застройки - 23 м, вид разрешенного
# использования: 4.9 — обслуживание автотранспорта, установив предельную
#  плотность застройки 48 тыс. кв.м./га, предельную высотность застройки
#  - 26 м, предельную застроенность участка 59%‚ вид разрешенного
# использования: 12.0 — общее пользование территории,по земельному
# участку с кадастровым номером 77:02:0003006:1241 установить следующие
# виды разрешенного использования: 2.6 — многоэтажная жилая застройка
# (высотная застройка), 2.7. — обслуживание жилой застройки, 3.5 —
# образование и просвещение, установив предельную плотность застройки 57
#  тыс. кв.м./га‚ предельную высотность застройки — 74 м, предельную
# застроенностъ - 41%; а также вид разрешенного использования: 4.0 —
# предпринимательство, установив предельную плотность застройки 17 тыс.
# кв.м./га, предельную высотность застройки - 23 м, вид разрешенного
# использования: 4.9 — обслуживание автотранспорта, установив предельную
#  плотность застройки 48 тыс. кв.м./га‚ предельную высотность застройки
#  - 26 м, предельную застроенность участка 59%‚ вид разрешенного
# использования: 12.0 — общее пользование территории, 2). Прошу внести
# изменения по земельным участкам территории ГБОУ школа № 1416 по
# адресам: ул. Новгородская, дом 8 и улица Новгородская, дом 6, в части
#          ------------------------- -------------------------
# дополнительного размещения двух блоков начальных классов емкостью 605
# мест. 3). По земельному участку, смежному с земельным участком с
# кадастровым номером 77:02:0003001:1‚ и расположенном в квартале
# 77:02:0003001 вид разрешенного использования 4.9 — обслуживание
# автотранспорта, установив предельную плотность застройки 32 тыс.
# кв.м./га, предельную высотность застройки - 16 м, предельную
# застроенность - 39%. параметров разрешенного строительства,
# реконструкции объектов капитального строительства на земельных
# участках в упомянутых зонах устанавливаются параметры расположенных на
#  указанных земельных участках объектов капитального строительства,
# сведения о которых содержатся в Едином государственном реестре
# недвижимости. 3).
# [
#   {
#     "parts": [
#       {
#         "name": "Новгородская",
#         "type": "улица"
#       },
#       {
#         "number": "8 и",
#         "type": "дом"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Новгородская",
#         "type": "улица"
#       },
#       {
#         "number": "6",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Предлагаю построить новый 25-й этажный дом на свободном месте,
# используя часть юго- восточного газона и площади под давно снесенным
# домом, по адресу: ул. Новогиреевская, д. 24, корп. 3-4
#                   ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Новогиреевская",
#         "type": "улица"
#       },
#       {
#         "number": "24",
#         "type": "дом"
#       },
#       {
#         "number": "3-4",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# Прошу достроить дом на ул.Живописная, 21 и благоустроить набережную
#                        -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21 и"
#       }
#     ]
#   }
# ]
# Исключить зону ООПТ с территории арендуемого земельного участка кад. №
#  7707:001 001 2 по адресу: ул. Крылатская, 37.
#                            ------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Крылатская",
#         "type": "улица"
#       },
#       {
#         "number": "37"
#       }
#     ]
#   }
# ]
# скорейшего завершения строительства дома по ул. Живопиная д. 21 и
#                                             ---------------------
# благоустройства набережной
# [
#   {
#     "parts": [
#       {
#         "name": "Живопиная",
#         "type": "улица"
#       },
#       {
#         "number": "21 и",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# С проектом Правил землепользования и застройки СВАО г. Москвы в целом
# согласен. Прошу внести следующие изменения в части земельных участков
# в районе Лианозово: 1). по земельному участку с кадастровым номером
# 77:02:0003001:1 установить следующие виды разрешенного использования:
# 2.6 — многоэтажная жилая застройка (высотная застройка), 2.7. —
# обслуживание жилой застройки, 3.5 — образование и просвещение,
# установив предельную плотность застройки 39 тыс. кв.м./га, предельную
# высотность застройки - 74 м, предельную застроенность - 29%; а также
# вид разрешенного использования: 4.0 — предпринимательство, установив
# предельную плотность застройки 17 тыс. кв.м./га, предельную высотность
#  застройки - 23 м, а также вид разрешенного использования: 4.9 —
# обслуживание автотранспорта, установив предельную плотность застройки
# 48 тыс. кв.м./га‚ предельную высотность застройки — 26 м. предельную
# застроенность участка 59%‚ и вид разрешенного использования: 12,0 —
# общее пользование территории, по земельному участку с кадастровым
# номером 77:02:0003002:2 установить следующие виды разрешенного
# использования: 2.6 — многоэтажная жилая застройка (высотная
# застройка), 2.7. — обслуживание жилой застройки, 3.5 — образование и
# просвещение, 4.9 — обслуживание автотранспорта, установив предельную
# плотность застройки 57 тыс. кв.м./га, предельную высотность застройки
# - 74 м, предельную застроенность - 41%; а также вид разрешенного
# использования: 4.0 — предпринимательство, установив предельную
# плотность застройки 17 тыс. кв.м./га, предельную высотность застройки
# - 23 м, вид разрешенного использования: 12.0 — общее пользование
# территории, по земельному участку с кадастровым номером
# 77:02:0003002:3330 установить следующие виды разрешенного
# использования: 2.6 — многоэтажная жилая застройка (высотная
# застройка), 2.7. — обслуживание жилой застройки, 3.5 — образование и
# просвещение, установив предельную плотность застройки 39 тыс.
# кв.м./га‚ предельную высотность застройки - 74 м, предельную
# застроенность - 29%; а также вид разрешенного использования: 4.0 —
# предпринимательство, установив предельную плотность застройки 17 тыс.
# кв.м./га, предельную высотность застройки - 23 м, вид разрешенного
# использования: 4.9 — обслуживание автотранспорта, установив предельную
#  плотность застройки 48 тыс. кв.м./га, предельную высотность застройки
#  - 26 м, предельную застроенность участка 59%‚ вид разрешенного
# использования: 12.0 — общее пользование территории,по земельному
# участку с кадастровым номером 77:02:0003006:1241 установить следующие
# виды разрешенного использования: 2.6 — многоэтажная жилая застройка
# (высотная застройка), 2.7. — обслуживание жилой застройки, 3.5 —
# образование и просвещение, установив предельную плотность застройки 57
#  тыс. кв.м./га‚ предельную высотность застройки — 74 м, предельную
# застроенностъ - 41%; а также вид разрешенного использования: 4.0 —
# предпринимательство, установив предельную плотность застройки 17 тыс.
# кв.м./га, предельную высотность застройки - 23 м, вид разрешенного
# использования: 4.9 — обслуживание автотранспорта, установив предельную
#  плотность застройки 48 тыс. кв.м./га‚ предельную высотность застройки
#  - 26 м, предельную застроенность участка 59%‚ вид разрешенного
# использования: 12.0 — общее пользование территории, 2). Прошу внести
# изменения по земельным участкам территории ГБОУ школа № 1416 по
# адресам: ул. Новгородская, дом 8 и улица Новгородская, дом 6, в части
#          ------------------------- -------------------------
# дополнительного размещения двух блоков начальных классов емкостью 605
# мест. 3). По земельному участку, смежному с земельным участком с
# кадастровым номером 77:02:0003001:1‚ и расположенном в квартале
# 77:02:0003001 вид разрешенного 1).использования 4.9 — обслуживание
# автотранспорта, установив предельную плотность застройки 32 тыс.
# кв.м./га, предельную высотность застройки - 16 м, предельную
# застроенность - 39%.
# [
#   {
#     "parts": [
#       {
#         "name": "Новгородская",
#         "type": "улица"
#       },
#       {
#         "number": "8 и",
#         "type": "дом"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Новгородская",
#         "type": "улица"
#       },
#       {
#         "number": "6",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Хорошо, что в Филях запланировано строительство многофункционального
# комплекса по адресу: ул.Заречная, д.2 \1. Больше двух тысяч семей это
#                      -------------------
# отличный прирост, я полностью одобряю данный проект.
# [
#   {
#     "parts": [
#       {
#         "name": "Заречная",
#         "type": "улица"
#       },
#       {
#         "number": "2 \\1",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# , Я Копыролин С.С. Председатель ТСЖ "Ивана Бабушикина" д.10 от имени
# жителей мгногоквартирного дома по адресу ул. Ивана Бабушкина д.10 не
#                                          ------------------------
# согласны с проектом ПЗЗ, вынесенным на публичные слушания в ЮЗАО г.
# Москвы, в связи с нарушением права интереса жителей. Категорически не
# согласны с проектом, поскольку не учитывает земельный участок ранее
# отеденный под застройку дома, согласна акта разрешенного строительства
#  использования градостроительного объекта от 02.04.2007 NA-3550/01.
# Проект не соответствует приложению градостроительного заключения от
# 28,12.2006г. №01-06-2006-06/301-06.
# [
#   {
#     "parts": [
#       {
#         "name": "Ивана Бабушкина",
#         "type": "улица"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ул. 2-ая Машиностроения,д.17, стр.1 по указанному адресу рассмотреть
# -----------------------------------
# возможность реконструкции здания в соответствии со следующими
# характеристиками: площадью помещения-13.000 кв.м., высота помещения -
# 20 м. (не более 5 этажей)
# [
#   {
#     "parts": [
#       {
#         "name": "2-ая Машиностроения",
#         "type": "улица"
#       },
#       {
#         "number": "17",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Участок по адресу Лужнецкий пр-д д.13А и 15, желательно на
#                   --------------------
# образовавшемся пустыре построить детский сад, в Хамовниках почти все
# д/с в первых этажах зданий, без собственной территории.
# [
#   {
#     "parts": [
#       {
#         "name": "Лужнецкий",
#         "type": "проезд"
#       },
#       {
#         "number": "13А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# построить дом на ул.Живописная, 21
#                  -----------------
# [
#   {
#     "parts": [
#       {
#         "name": "Живописная",
#         "type": "улица"
#       },
#       {
#         "number": "21"
#       }
#     ]
#   }
# ]
# Я, Кузнецов Илья Димитрович, житель района Пресненский ЦАО г.Москвы,
# проживающий по адресу: Гранатный пер., д.11, стр.1, кв.9, против
#                        ---------------------------------
# строительства гостинницы на участке по адресу: Гранатный пер., вл.6,
# стр.1. Гранатный переулок в городе Москве - это тихое и уютное
# историческое место, улица, на которой в основном расположены жилые
# дома. Иностранный девелопер (Компания "Интеркар Трейдинг Лимитед")
# арендатор участка, собирается построить аппарт-отель, который точно не
#  вернет мемориальеной ценности дому Майкова, который ранее
# располагался на этом участке, строительство аппатр-отеля будет
# сопровождаться проездом строительной техники и повышенным уровнем
# шума, грязью и строительным мусором, что причинит значительные
# неудобства жителям. Кроме того строительство аппарт-отеля на месте
# исторического особняка повлечет за собой увеличение антропогенной
# нагрузки. Строительство на этом участке приведет к нарушению моих прав
#  и законных интересов, втом числе права на благоприятную окружающую
# среду , а так-жесущественно ухудшит условия проживания. В этой связи
# счмтаю, что ГПЗУ №RU 77- 181000-020710 вообще необходимо аннулировать
# [
#   {
#     "parts": [
#       {
#         "name": "Гранатный",
#         "type": "переулок"
#       },
#       {
#         "number": "11",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       },
#       {
#         "number": "9",
#         "type": "квартира"
#       }
#     ]
#   }
# ]
