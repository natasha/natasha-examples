# %%
texts = []
with open('sample.txt') as file:
    for line in file:
        texts.append(line.rstrip())

# %%
from random import seed, sample

from natasha import AddressExtractor
from natasha.markup import show_json, show_markup

extractor = AddressExtractor() 

seed(43)
for text in sample(texts, 200):
    matches = extractor(text)
    spans = [_.span for _ in matches]
    show_markup(text, spans)
    facts = [_.fact.as_json for _ in matches]
    show_json(facts)
# Out:
# г. Самара, ул. Стара Загора, 25, оф. 92
# ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Самара",
#         "type": "город"
#       },
#       {
#         "name": "Стара Загора",
#         "type": "улица"
#       },
#       {
#         "number": "25"
#       },
#       {
#         "number": "92",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г. Ухта, ул. Бушуева, д. 14,. т. 73-26-58
# ---------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ухта",
#         "type": "город"
#       },
#       {
#         "name": "Бушуева",
#         "type": "улица"
#       },
#       {
#         "number": "14",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 127282, г. Москва, ул. Полярная, д. 41, строение 1
# --------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "127282"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Полярная",
#         "type": "улица"
#       },
#       {
#         "number": "41",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Стерлитамак, ул. Худайбердина, д.76 пом.1
# -----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Стерлитамак"
#       },
#       {
#         "name": "Худайбердина",
#         "type": "улица"
#       },
#       {
#         "number": "76",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Беларусь, 220020, г. Минск, пр. Победителей, д. 103, офис 1408 (БЦ
#           ----------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "220020"
#       },
#       {
#         "name": "Минск",
#         "type": "город"
#       },
#       {
#         "name": "Победителей",
#         "type": "проспект"
#       },
#       {
#         "number": "103",
#         "type": "дом"
#       },
#       {
#         "number": "1408",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г. Екатеринбург, ул. Бархотская, 2
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Екатеринбург",
#         "type": "город"
#       },
#       {
#         "name": "Бархотская",
#         "type": "улица"
#       },
#       {
#         "number": "2"
#       }
#     ]
#   }
# ]
# 601440, г. Вязники, Владимирская область, микрорайон Дечинский, д. 11.
# []
# Краснодарский край, г. Ейск, ул. Краснофлотская 53
# --------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Краснодарский",
#         "type": "край"
#       },
#       {
#         "name": "Ейск",
#         "type": "город"
#       },
#       {
#         "name": "Краснофлотская",
#         "type": "улица"
#       },
#       {
#         "number": "53"
#       }
#     ]
#   }
# ]
# 353691, Ейск г, Коммунистическая ул, д.85/6, оф. 10 , («Ейск
#                 -----------------------------------
# Коммунистическая_2349_С
# [
#   {
#     "parts": [
#       {
#         "name": "Коммунистическая",
#         "type": "улица"
#       },
#       {
#         "number": "85/6",
#         "type": "дом"
#       },
#       {
#         "number": "10",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# типография: г.Люберцы, ул. Инициативная, д.5
#             --------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Люберцы",
#         "type": "город"
#       },
#       {
#         "name": "Инициативная",
#         "type": "улица"
#       },
#       {
#         "number": "5",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Коровинское шоссе, д. 35, стр. 2
# --------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Коровинское",
#         "type": "шоссе"
#       },
#       {
#         "number": "35",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# 620041, г. Екатеринбург, ул. Уральская,д.48/93
# ----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "620041"
#       },
#       {
#         "name": "Екатеринбург",
#         "type": "город"
#       },
#       {
#         "name": "Уральская",
#         "type": "улица"
#       },
#       {
#         "number": "48/93",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Санкт-Петербург, пр. Космонавтов, дом 61, корпус 1
# --------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Санкт-Петербург"
#       },
#       {
#         "name": "Космонавтов",
#         "type": "проспект"
#       },
#       {
#         "number": "61",
#         "type": "дом"
#       },
#       {
#         "number": "1",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# Тюменская область, г. Тобольск, ул. С. Ремезова, 27 (1
# ---------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Тюменская",
#         "type": "область"
#       },
#       {
#         "name": "Тобольск",
#         "type": "город"
#       },
#       {
#         "name": "С. Ремезова",
#         "type": "улица"
#       },
#       {
#         "number": "27"
#       }
#     ]
#   }
# ]
# 167000, г.Сыктывкар, ул.Интернациональная, д.157
# ------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "167000"
#       },
#       {
#         "name": "Сыктывкар",
#         "type": "город"
#       },
#       {
#         "name": "Интернациональная",
#         "type": "улица"
#       },
#       {
#         "number": "157",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ООО ""Графика"", 127055, Москва, ул. Новолесная, д. 5
#                  ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "127055"
#       },
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Новолесная",
#         "type": "улица"
#       },
#       {
#         "number": "5",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# "г. Ростов-на-Дону, ул. Ленина, 245/2 оф.2
#  -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ростов-на-Дону",
#         "type": "город"
#       },
#       {
#         "name": "Ленина",
#         "type": "улица"
#       },
#       {
#         "number": "245/2"
#       },
#       {
#         "number": "2",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# 690105 г. Владивосток, ул. Русская, 65/4, офис 46
# -------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "690105"
#       },
#       {
#         "name": "Владивосток",
#         "type": "город"
#       },
#       {
#         "name": "Русская",
#         "type": "улица"
#       },
#       {
#         "number": "65/4"
#       },
#       {
#         "number": "46",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Юр. и фактический адрес: 141205, Московская область, Пушкинский р-н,
#                          --------------------------------------------
# г. Пушкино, Ярославское шоссе, д.64
# -----------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "141205"
#       },
#       {
#         "name": "Московская",
#         "type": "область"
#       },
#       {
#         "name": "Пушкинский",
#         "type": "район"
#       },
#       {
#         "name": "Пушкино",
#         "type": "город"
#       },
#       {
#         "name": "Ярославское",
#         "type": "шоссе"
#       },
#       {
#         "number": "64",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Кирпичный завод г Новосибирск, ул. Галущака, д. 2
#                 ---------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Новосибирск",
#         "type": "город"
#       },
#       {
#         "name": "Галущака",
#         "type": "улица"
#       },
#       {
#         "number": "2",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Наш адрес:| 125438, г.Москва, ул.Михалковская, д.63Б стр.4 БЦ
#             ----------------------------------------------
# "Головинские Пруды"
# [
#   {
#     "parts": [
#       {
#         "value": "125438"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Михалковская",
#         "type": "улица"
#       },
#       {
#         "number": "63Б",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# 238321, Калининградская область, Гурьевский район, п.Константиновка,
# ул.Берѐзовая, д.1
# []
# Адрес: | 628418, Тюменская область, Ханты-Мансийский автономный округ,
#  г. Сургут, ул. Островского, д.45/1
#  ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Сургут",
#         "type": "город"
#       },
#       {
#         "name": "Островского",
#         "type": "улица"
#       },
#       {
#         "number": "45/1",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 109147, г. Москва, ул. Марксистская, д. 20 стр. 1, пом II, комн. 1
# -------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "109147"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Марксистская",
#         "type": "улица"
#       },
#       {
#         "number": "20",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# ул.Растопчина, д.61а, 2-комнатная квартира на 1/5 панельного дома,
# --------------------
# 53/30/9. ""Чешка - распашонка"" в х
# [
#   {
#     "parts": [
#       {
#         "name": "Растопчина",
#         "type": "улица"
#       },
#       {
#         "number": "61а",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Москва, ул.Малыгина, д. 5, корп. 1
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Малыгина",
#         "type": "улица"
#       },
#       {
#         "number": "5",
#         "type": "дом"
#       },
#       {
#         "number": "1",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# г. Москва Красногвардейский бульвар 3 строение 1
# ------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Красногвардейский",
#         "type": "бульвар"
#       },
#       {
#         "number": "3"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# г. Суджа, (47143) 2-42-39
# []
# ООО «Стройтекс», г. Новосибирск, ул. Дуси Ковальчук, 2/2, тел./факс:
#                  ---------------------------------------
# (383) 246-00-06
# [
#   {
#     "parts": [
#       {
#         "name": "Новосибирск",
#         "type": "город"
#       },
#       {
#         "name": "Дуси Ковальчук",
#         "type": "улица"
#       },
#       {
#         "number": "2/2"
#       }
#     ]
#   }
# ]
# Москва, ул. Александра Солженицына, дом 31, стр.1 и
# ---------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Александра Солженицына",
#         "type": "улица"
#       },
#       {
#         "number": "31",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# ул. Ново-Ямская, д. 72, офис 7
# ------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ново-Ямская",
#         "type": "улица"
#       },
#       {
#         "number": "72",
#         "type": "дом"
#       },
#       {
#         "number": "7",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Уфа | Бьюти Маркет | Проспект Октября, д. 48
#                      -----------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Октября",
#         "type": "проспект"
#       },
#       {
#         "number": "48",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ООО «ВАЛЕАНТ», 115162, г. Москва, ул. Шаболовка, д.31, стр. 5. Сайт
#                ----------------------------------------------
# предназначен для физических и юридических лиц из России и СНГ
# [
#   {
#     "parts": [
#       {
#         "value": "115162"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Шаболовка",
#         "type": "улица"
#       },
#       {
#         "number": "31",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# ул. Большая Почтовая, д. 7, стр. 1
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Большая Почтовая",
#         "type": "улица"
#       },
#       {
#         "number": "7",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Адрес: г. Санкт-Петербург, ул. Белы Куна, д. 20
#        ----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Санкт-Петербург",
#         "type": "город"
#       },
#       {
#         "name": "Белы Куна",
#         "type": "улица"
#       },
#       {
#         "number": "20",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Юридический адрес:| 430008, Республика Мордовия, г. Саранск, р.п.
#                     ----------------------------------------------
# Луховка, ул. Рабочая, д.33, кв.(офис) 46
# --------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "430008"
#       },
#       {
#         "name": "Мордовия",
#         "type": "республика"
#       },
#       {
#         "name": "Саранск",
#         "type": "город"
#       },
#       {
#         "name": "Луховка",
#         "type": "посёлок"
#       },
#       {
#         "name": "Рабочая",
#         "type": "улица"
#       },
#       {
#         "number": "33",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 127254, Москва, Огородный проезд, 16 (ст. м
# ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "127254"
#       },
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Огородный",
#         "type": "проезд"
#       },
#       {
#         "number": "16"
#       }
#     ]
#   }
# ]
# Факт. Адрес г. Тверь ул. Горького 107
#             -------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Тверь",
#         "type": "город"
#       },
#       {
#         "name": "Горького",
#         "type": "улица"
#       },
#       {
#         "number": "107"
#       }
#     ]
#   }
# ]
# 693000, г.Южно-Сахалинск, ул.Авиационная, 74"
# --------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "693000"
#       },
#       {
#         "name": "Южно-Сахалинск",
#         "type": "город"
#       },
#       {
#         "name": "Авиационная",
#         "type": "улица"
#       },
#       {
#         "number": "74"
#       }
#     ]
#   }
# ]
# 620105 г. Екатеринбург, ул. Таежная, д. 7
# -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "620105"
#       },
#       {
#         "name": "Екатеринбург",
#         "type": "город"
#       },
#       {
#         "name": "Таежная",
#         "type": "улица"
#       },
#       {
#         "number": "7",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 394030, Россия, г. Воронеж, ул. Кости Стрелюка д. 16А
# -----------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "394030"
#       },
#       {
#         "name": "Россия"
#       },
#       {
#         "name": "Воронеж",
#         "type": "город"
#       },
#       {
#         "name": "Кости Стрелюка",
#         "type": "улица"
#       },
#       {
#         "number": "16А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Муром, Радиозаводское шоссе, д.23
# ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Муром",
#         "type": "город"
#       },
#       {
#         "name": "Радиозаводское",
#         "type": "шоссе"
#       },
#       {
#         "number": "23",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ул. Раздольная, д. 1Ж
# ---------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Раздольная",
#         "type": "улица"
#       },
#       {
#         "number": "1Ж",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 454010, Россия, г. Челябинск, ул. Енисейская, 75Б
# -------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "454010"
#       },
#       {
#         "name": "Россия"
#       },
#       {
#         "name": "Челябинск",
#         "type": "город"
#       },
#       {
#         "name": "Енисейская",
#         "type": "улица"
#       },
#       {
#         "number": "75Б"
#       }
#     ]
#   }
# ]
# ООО ""Дикси "" Юридический адрес: 198097, Россия, Санкт-Петербург, пр.
#                                   ------------------------------------
#  Маршала Говорова д. 29 лит.А, ОГРН 1037711013295"
# -----------------------
# [
#   {
#     "parts": [
#       {
#         "value": "198097"
#       },
#       {
#         "name": "Россия"
#       },
#       {
#         "name": "Санкт-Петербург"
#       },
#       {
#         "name": "Маршала Говорова",
#         "type": "проспект"
#       },
#       {
#         "number": "29",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# пер.Саранинский, д.9
# --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Саранинский",
#         "type": "переулок"
#       },
#       {
#         "number": "9",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 308009, г. Белгород, Народный бульвар, 55, к.205
# -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "308009"
#       },
#       {
#         "name": "Белгород",
#         "type": "город"
#       },
#       {
#         "name": "Народный",
#         "type": "бульвар"
#       },
#       {
#         "number": "55"
#       }
#     ]
#   }
# ]
# ТС Карусель| г.Санкт-Петербург| Коломяжский пр-т д. 17А
#                                 -----------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Коломяжский",
#         "type": "проспект"
#       },
#       {
#         "number": "17А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Санкт-Петербург, ул. Большая Посадская, д. 1/10
# --------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Санкт-Петербург",
#         "type": "город"
#       },
#       {
#         "name": "Большая Посадская",
#         "type": "улица"
#       },
#       {
#         "number": "1/10",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Адрес: г. Оренбург, пр. Автоматики, 12 (магазин Двери)
#        -------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Оренбург",
#         "type": "город"
#       },
#       {
#         "name": "Автоматики",
#         "type": "проспект"
#       },
#       {
#         "number": "12"
#       }
#     ]
#   }
# ]
# 1 -- пешком 1км от метро «Гагаринская» или троллейбус №13 ост.
# «ул.Писарева
# []
# Москва, Хорошевское шоссе, дом 12, корпус 1, 3-й
# -------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Хорошевское",
#         "type": "шоссе"
#       },
#       {
#         "number": "12",
#         "type": "дом"
#       },
#       {
#         "number": "1",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# ул. Ленинская Слобода, д. 26
# ----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ленинская Слобода",
#         "type": "улица"
#       },
#       {
#         "number": "26",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ул. Ошарская, д. 69
# -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ошарская",
#         "type": "улица"
#       },
#       {
#         "number": "69",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# "141070, Московская область, г. Королев, пр. Космонавтов, д. 34Б, офис
#  ---------------------------------------------------------------------
#  417. (ТДЦ ""Юпитер"", 4
# ----
# [
#   {
#     "parts": [
#       {
#         "value": "141070"
#       },
#       {
#         "name": "Московская",
#         "type": "область"
#       },
#       {
#         "name": "Королев",
#         "type": "город"
#       },
#       {
#         "name": "Космонавтов",
#         "type": "проспект"
#       },
#       {
#         "number": "34Б",
#         "type": "дом"
#       },
#       {
#         "number": "417",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г. Тула, ул. Чмутова, д. 1 В
# ----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Тула",
#         "type": "город"
#       },
#       {
#         "name": "Чмутова",
#         "type": "улица"
#       },
#       {
#         "number": "1 В",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# "г. Тула, ул. Советская, д.60, оф. 24
#  ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Тула",
#         "type": "город"
#       },
#       {
#         "name": "Советская",
#         "type": "улица"
#       },
#       {
#         "number": "60",
#         "type": "дом"
#       },
#       {
#         "number": "24",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Научный проезд ,д.19 (Административное здание, офисы только для
# --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Научный",
#         "type": "проезд"
#       },
#       {
#         "number": "19",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Иркутск, ул. Декабрьских событий 119 А. офис 401
# -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Иркутск",
#         "type": "город"
#       },
#       {
#         "name": "Декабрьских событий",
#         "type": "улица"
#       },
#       {
#         "number": "119 А"
#       }
#     ]
#   }
# ]
# Москва, 125212, Головинское шоссе 8 корпус 2A
# --------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "value": "125212"
#       },
#       {
#         "name": "Головинское",
#         "type": "шоссе"
#       },
#       {
#         "number": "8"
#       },
#       {
#         "number": "2",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# -- Белгородская область,  Старооскольский район, с. Ивановка, ул.
#    ---------------------------------------------------------------
# Молодежная, Дом 9;
# -----------------
# [
#   {
#     "parts": [
#       {
#         "name": "Белгородская",
#         "type": "область"
#       },
#       {
#         "name": "Старооскольский",
#         "type": "район"
#       },
#       {
#         "name": "Ивановка",
#         "type": "село"
#       },
#       {
#         "name": "Молодежная",
#         "type": "улица"
#       },
#       {
#         "number": "9",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Московская область, Долгопрудный, Ленинградская улица, 10а
# ----------------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Московская",
#         "type": "область"
#       },
#       {
#         "name": "Долгопрудный"
#       },
#       {
#         "name": "Ленинградская",
#         "type": "улица"
#       },
#       {
#         "number": "10а"
#       }
#     ]
#   }
# ]
# г.Москва п.Ватутинки-1. д.13 (3 Ватутинская дом 5
# []
# г. Благовещенск, ул. Горького, 64
# ---------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Благовещенск",
#         "type": "город"
#       },
#       {
#         "name": "Горького",
#         "type": "улица"
#       },
#       {
#         "number": "64"
#       }
#     ]
#   }
# ]
# Офис корпоративного страхования Казань, ул. Пушкина, д.11
#                                 -------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Казань"
#       },
#       {
#         "name": "Пушкина",
#         "type": "улица"
#       },
#       {
#         "number": "11",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Саратов, ул. Танкистов, 84 А
# -------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Саратов",
#         "type": "город"
#       },
#       {
#         "name": "Танкистов",
#         "type": "улица"
#       },
#       {
#         "number": "84 А"
#       }
#     ]
#   }
# ]
# Новорязанская ул., д.18, стр. 21
# --------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Новорязанская",
#         "type": "улица"
#       },
#       {
#         "number": "18",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# г. Красноярск. ул. Сурикова, 6
#                ---------------
# [
#   {
#     "parts": [
#       {
#         "name": "Сурикова",
#         "type": "улица"
#       },
#       {
#         "number": "6"
#       }
#     ]
#   }
# ]
# 143966, г. Реутов Московской области, улица Фабричная, дом 15.
# -------------------------------------------------------------
# Телефоны:+7 (499) 703 0426. E-mail:kabelplast@bk
# [
#   {
#     "parts": [
#       {
#         "value": "143966"
#       },
#       {
#         "name": "Реутов",
#         "type": "город"
#       },
#       {
#         "name": "Московской",
#         "type": "область"
#       },
#       {
#         "name": "Фабричная",
#         "type": "улица"
#       },
#       {
#         "number": "15",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 624090 Свердловская область, г.Верхняя Пышма, пр-т Успенский, 42а
# -----------------------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "624090"
#       },
#       {
#         "name": "Свердловская",
#         "type": "область"
#       },
#       {
#         "name": "Верхняя Пышма",
#         "type": "город"
#       },
#       {
#         "name": "Успенский",
#         "type": "проспект"
#       },
#       {
#         "number": "42а"
#       }
#     ]
#   }
# ]
# г. Ярославль, ул. 1905 года, д.15
# ---------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ярославль",
#         "type": "город"
#       },
#       {
#         "name": "1905 года",
#         "type": "улица"
#       },
#       {
#         "number": "15",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Москва, Новая площадь дом 8
# ------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Новая",
#         "type": "площадь"
#       },
#       {
#         "number": "8",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 150049, г. Ярославль,  ул. Лисицына, д.5, оф.115
# ------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "150049"
#       },
#       {
#         "name": "Ярославль",
#         "type": "город"
#       },
#       {
#         "name": "Лисицына",
#         "type": "улица"
#       },
#       {
#         "number": "5",
#         "type": "дом"
#       },
#       {
#         "number": "115",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г.Осинники, ул.50 лет Рудника 14                             |
# --------------------------------
# круглосуточно             | 838471-5-22-52
# [
#   {
#     "parts": [
#       {
#         "name": "Осинники",
#         "type": "город"
#       },
#       {
#         "name": "50 лет Рудника",
#         "type": "улица"
#       },
#       {
#         "number": "14"
#       }
#     ]
#   }
# ]
# 308019, Белгородская область, г. Белгород, ул. Магистральная, д.55
# ------------------------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "308019"
#       },
#       {
#         "name": "Белгородская",
#         "type": "область"
#       },
#       {
#         "name": "Белгород",
#         "type": "город"
#       },
#       {
#         "name": "Магистральная",
#         "type": "улица"
#       },
#       {
#         "number": "55",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Волгоград, ул. им. 51-й Гвардейской дивизии, д. 1А
# --------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Волгоград"
#       },
#       {
#         "name": "им. 51-й Гвардейской дивизии",
#         "type": "улица"
#       },
#       {
#         "number": "1А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Екатеринбург, пр. Космонавтов, д. 6
# --------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Екатеринбург",
#         "type": "город"
#       },
#       {
#         "name": "Космонавтов",
#         "type": "проспект"
#       },
#       {
#         "number": "6",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Тула ул. Советская д.67, bct
# --------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Тула",
#         "type": "город"
#       },
#       {
#         "name": "Советская",
#         "type": "улица"
#       },
#       {
#         "number": "67",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# -фактический адрес осуществления заявленного вида деятельности:
# 428024, г. Чебоксары, пр.Мира 90 корп.2
# ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "428024"
#       },
#       {
#         "name": "Чебоксары",
#         "type": "город"
#       },
#       {
#         "name": "Мира",
#         "type": "проспект"
#       },
#       {
#         "number": "90"
#       },
#       {
#         "number": "2",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# 188508, Ленинградская область, Ломоносовский район, Виллози деревня,
# Волхонское шоссе., дом 4, литера А
# []
# Банк получателя:| ОО "Ростовский" ПАО "Промсвязьбанк" г. Ростов-на-
#                                                       -------------
# Дону, ул Большая Садовая, д. 36/21/38
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ростов-на-Дону",
#         "type": "город"
#       },
#       {
#         "name": "Большая Садовая",
#         "type": "улица"
#       },
#       {
#         "number": "36/21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 620042, Свердловская обл, Екатеринбург г, Коммунистическая ул, дом №
#                                           ---------------------------
# 50 В
# ----
# [
#   {
#     "parts": [
#       {
#         "name": "Коммунистическая",
#         "type": "улица"
#       },
#       {
#         "number": "№ 50 В",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Почтовый адрес: 420036, г.Казань, ул.Копылова, д.2, стадион «Рубин»,
#                 ----------------------------------
# восточная трибуна
# [
#   {
#     "parts": [
#       {
#         "value": "420036"
#       },
#       {
#         "name": "Казань",
#         "type": "город"
#       },
#       {
#         "name": "Копылова",
#         "type": "улица"
#       },
#       {
#         "number": "2",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# в г. Кемерово вы можете по адресу: ул.Терешковой, 52
#                                    -----------------
# [
#   {
#     "parts": [
#       {
#         "name": "Терешковой",
#         "type": "улица"
#       },
#       {
#         "number": "52"
#       }
#     ]
#   }
# ]
# г.Красноярск, ул.Калинина, 183
# ------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Красноярск",
#         "type": "город"
#       },
#       {
#         "name": "Калинина",
#         "type": "улица"
#       },
#       {
#         "number": "183"
#       }
#     ]
#   }
# ]
# 25.08.2017 11:32 | Кофе | Ситдиков Эльдар Закариевич | АЗС № 56-026,
# Оренбургская область, г. Оренбург, пр. Победы, 162/1
# ----------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Оренбургская",
#         "type": "область"
#       },
#       {
#         "name": "Оренбург",
#         "type": "город"
#       },
#       {
#         "name": "Победы",
#         "type": "проспект"
#       },
#       {
#         "number": "162/1"
#       }
#     ]
#   }
# ]
# Московская обл., Солнечногорский р-н, р.п. Андреевка, д.28
# []
# 6\. г. Краснодар ул. Российская, д. 267/3 к1
#     ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Краснодар",
#         "type": "город"
#       },
#       {
#         "name": "Российская",
#         "type": "улица"
#       },
#       {
#         "number": "267/3 к",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Пенза, ул. Клары Цеткин 55, ТЦ
# -----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Пенза",
#         "type": "город"
#       },
#       {
#         "name": "Клары Цеткин",
#         "type": "улица"
#       },
#       {
#         "number": "55"
#       }
#     ]
#   }
# ]
# Адрес: 241047 г.Брянск, ул. Фосфоритная, 1В
#        ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "241047"
#       },
#       {
#         "name": "Брянск",
#         "type": "город"
#       },
#       {
#         "name": "Фосфоритная",
#         "type": "улица"
#       },
#       {
#         "number": "1В"
#       }
#     ]
#   }
# ]
# г. Бор, Стеклозаводское шоссе, д.3 (1й
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Бор",
#         "type": "город"
#       },
#       {
#         "name": "Стеклозаводское",
#         "type": "шоссе"
#       },
#       {
#         "number": "3",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 683032, Камчатский край, г. Петропавловск-Камчатский, ул. Максутова,
# ---------------------------------------------------------------------
# д. 44
# -----
# [
#   {
#     "parts": [
#       {
#         "value": "683032"
#       },
#       {
#         "name": "Камчатский",
#         "type": "край"
#       },
#       {
#         "name": "Петропавловск-Камчатский",
#         "type": "город"
#       },
#       {
#         "name": "Максутова",
#         "type": "улица"
#       },
#       {
#         "number": "44",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Мытищи, Олимпийский пр-т, д. 21, ТЦ
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Мытищи",
#         "type": "город"
#       },
#       {
#         "name": "Олимпийский",
#         "type": "проспект"
#       },
#       {
#         "number": "21",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г.Оренбург, ул.Магистральная, 20
# --------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Оренбург",
#         "type": "город"
#       },
#       {
#         "name": "Магистральная",
#         "type": "улица"
#       },
#       {
#         "number": "20"
#       }
#     ]
#   }
# ]
# г. Армавир, маг. Фаворит, ул. Новороссийская, 129/1 тел:
#                           -------------------------
# (86137)5-62-66
# [
#   {
#     "parts": [
#       {
#         "name": "Новороссийская",
#         "type": "улица"
#       },
#       {
#         "number": "129/1"
#       }
#     ]
#   }
# ]
# Адрес: ул. Ямашева проспект, 95
#            --------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ямашева",
#         "type": "проспект"
#       },
#       {
#         "number": "95"
#       }
#     ]
#   }
# ]
# 658080 г. Новоалтайск, ул. Космонавтов, д. 16А
# ----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "658080"
#       },
#       {
#         "name": "Новоалтайск",
#         "type": "город"
#       },
#       {
#         "name": "Космонавтов",
#         "type": "улица"
#       },
#       {
#         "number": "16А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Адрес: 614077, г. Пермь, ул. Техническая, 7
#        ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "614077"
#       },
#       {
#         "name": "Пермь",
#         "type": "город"
#       },
#       {
#         "name": "Техническая",
#         "type": "улица"
#       },
#       {
#         "number": "7"
#       }
#     ]
#   }
# ]
# 634050, г. Томск, ул. Советская, д. 2, оф. 6
# --------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "634050"
#       },
#       {
#         "name": "Томск",
#         "type": "город"
#       },
#       {
#         "name": "Советская",
#         "type": "улица"
#       },
#       {
#         "number": "2",
#         "type": "дом"
#       },
#       {
#         "number": "6",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# 623101, Свердловская область, г. Первоуральск, пр. Космонавтов, 19
# ------------------------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "623101"
#       },
#       {
#         "name": "Свердловская",
#         "type": "область"
#       },
#       {
#         "name": "Первоуральск",
#         "type": "город"
#       },
#       {
#         "name": "Космонавтов",
#         "type": "проспект"
#       },
#       {
#         "number": "19"
#       }
#     ]
#   }
# ]
# 152253, Ярославская область, Гаврилов-Ямский район, деревня Шалаево,
#                                       -------------------------------
# ул. Центральная 4
# -----------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ямский",
#         "type": "район"
#       },
#       {
#         "name": "Шалаево",
#         "type": "деревня"
#       },
#       {
#         "name": "Центральная",
#         "type": "улица"
#       },
#       {
#         "number": "4"
#       }
#     ]
#   }
# ]
# ст.метро «Площадь Александра Невского»: автобус № 8, троллейбус № 16,
# маршрутное такси К-8, К-16 - до остановки «Институт им. В.М
# []
# 620031, Екатеринбург, ул. Бориса Ельцина, д.10
# ----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "620031"
#       },
#       {
#         "name": "Екатеринбург"
#       },
#       {
#         "name": "Бориса Ельцина",
#         "type": "улица"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 248023, г. Калуга, ул. Тульская, д. 189, стр. 2
# -----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "248023"
#       },
#       {
#         "name": "Калуга",
#         "type": "город"
#       },
#       {
#         "name": "Тульская",
#         "type": "улица"
#       },
#       {
#         "number": "189",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# г. Москва ул. Расплетина, д. 13, офис 4 | Пн.-Пт. 10:00-20:00
# ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Расплетина",
#         "type": "улица"
#       },
#       {
#         "number": "13",
#         "type": "дом"
#       },
#       {
#         "number": "4",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Дружинниковская улица, д. 15
# ----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Дружинниковская",
#         "type": "улица"
#       },
#       {
#         "number": "15",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Юридический и фактический адрес: 443022, г. Самара, пр-кт Кирова, 24,
#                                  -------------------------------------
# стр.1,оф.66
# -----------
# [
#   {
#     "parts": [
#       {
#         "value": "443022"
#       },
#       {
#         "name": "Самара",
#         "type": "город"
#       },
#       {
#         "name": "Кирова",
#         "type": "проспект"
#       },
#       {
#         "number": "24"
#       },
#       {
#         "type": "строение"
#       },
#       {
#         "number": "66",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г.Октябрьский, ул.Северная 21А
# ------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Октябрьский",
#         "type": "город"
#       },
#       {
#         "name": "Северная",
#         "type": "улица"
#       },
#       {
#         "number": "21А"
#       }
#     ]
#   }
# ]
# г. Нижний Новгород, ул. Сутырина, 32, А показать на карте
# ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Нижний Новгород",
#         "type": "город"
#       },
#       {
#         "name": "Сутырина",
#         "type": "улица"
#       },
#       {
#         "number": "32"
#       }
#     ]
#   }
# ]
# Адрес: | г. Павловский Посад, ул. Карповская, д.4
#          ----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Павловский Посад",
#         "type": "город"
#       },
#       {
#         "name": "Карповская",
#         "type": "улица"
#       },
#       {
#         "number": "4",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Улица Берёзовая дом 3, 1 этаж офис №9
# ---------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Берёзовая",
#         "type": "улица"
#       },
#       {
#         "number": "3",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 162603,  Россия,  Вологодская область,  г. Череповец,  пр. Победы, д.
# ----------------------------------------------------------------------
# 85Г"
# ---
# [
#   {
#     "parts": [
#       {
#         "value": "162603"
#       },
#       {
#         "name": "Россия"
#       },
#       {
#         "name": "Вологодская",
#         "type": "область"
#       },
#       {
#         "name": "Череповец",
#         "type": "город"
#       },
#       {
#         "name": "Победы",
#         "type": "проспект"
#       },
#       {
#         "number": "85Г",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Старопетровский проезд д.7А стр.6
# ---------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Старопетровский",
#         "type": "проезд"
#       },
#       {
#         "number": "7А",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# Москва, ул. Садовая-Каретная д. 8 стр. 1. Метро Маяковская,
# ----------------------------------------
# Новослободская, Пушкинская
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Садовая-Каретная",
#         "type": "улица"
#       },
#       {
#         "number": "8",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# 119634, г. Москва, ул. Лукинская, д. 16, к.1, офис 12
# ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "119634"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Лукинская",
#         "type": "улица"
#       },
#       {
#         "number": "16",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Иваново, проспект Ленина, д.43 (остановка ""площадь Ленина
# ------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Иваново"
#       },
#       {
#         "name": "Ленина",
#         "type": "проспект"
#       },
#       {
#         "number": "43",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Свердловская область, Екатеринбург, ул. Бакинских Комиссаров 112 и ул.
# ------------------------------------------------------------------ ---
#  Бетонщиков 5
# -------------
# [
#   {
#     "parts": [
#       {
#         "name": "Свердловская",
#         "type": "область"
#       },
#       {
#         "name": "Екатеринбург"
#       },
#       {
#         "name": "Бакинских Комиссаров",
#         "type": "улица"
#       },
#       {
#         "number": "112 и"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Бетонщиков",
#         "type": "улица"
#       },
#       {
#         "number": "5"
#       }
#     ]
#   }
# ]
# 153043 г.Иваново,ул.Калашникова,28
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "153043"
#       },
#       {
#         "name": "Иваново",
#         "type": "город"
#       },
#       {
#         "name": "Калашникова",
#         "type": "улица"
#       },
#       {
#         "number": "28"
#       }
#     ]
#   }
# ]
# Bar"" г. Сыктывкар, ул. Коммунистическая, д. 50, ТРЦ
#       -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Сыктывкар",
#         "type": "город"
#       },
#       {
#         "name": "Коммунистическая",
#         "type": "улица"
#       },
#       {
#         "number": "50",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 170002, Тверская обл., город Тверь, проспект Чайковского, дом 84А,
# -------------------------------------------------------------------
# оф.11
# -----
# [
#   {
#     "parts": [
#       {
#         "value": "170002"
#       },
#       {
#         "name": "Тверская",
#         "type": "область"
#       },
#       {
#         "name": "Тверь",
#         "type": "город"
#       },
#       {
#         "name": "Чайковского",
#         "type": "проспект"
#       },
#       {
#         "number": "84А",
#         "type": "дом"
#       },
#       {
#         "number": "11",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# ул. Земляной Вал, д. 34, стр. 4
# -------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Земляной Вал",
#         "type": "улица"
#       },
#       {
#         "number": "34",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# 129085, г. Москва, Звездный б-р, 21/1
# -------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "129085"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Звездный",
#         "type": "бульвар"
#       },
#       {
#         "number": "21/1"
#       }
#     ]
#   }
# ]
# ул. Гагарина, д. 81
# -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Гагарина",
#         "type": "улица"
#       },
#       {
#         "number": "81",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Санкт-Петербург, Пушкинский р-н, пос. Шушары, ул. Ленина,  д. 1БА
# ------------------------------------------------------------------
# (около 1 км от КАД
# [
#   {
#     "parts": [
#       {
#         "name": "Санкт-Петербург",
#         "type": "город"
#       },
#       {
#         "name": "Пушкинский",
#         "type": "район"
#       },
#       {
#         "name": "Шушары",
#         "type": "посёлок"
#       },
#       {
#         "name": "Ленина",
#         "type": "улица"
#       },
#       {
#         "number": "1",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 617600, с. Усть-Кишерть, ул. Комсомольская, д. 5
# ------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "617600"
#       },
#       {
#         "name": "Усть-Кишерть",
#         "type": "село"
#       },
#       {
#         "name": "Комсомольская",
#         "type": "улица"
#       },
#       {
#         "number": "5",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 01.08.2017 11:44 | Кофе | Якупов Дамир Забирович | АЗС № 02-151,
# Республика Башкортостан, г.Уфа, Калининский район, по пр.Октября в
# районе поворота на ул
# []
# 610000, г. Киров, ул. Свободы, д. 67 (1 этаж)
# ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "610000"
#       },
#       {
#         "name": "Киров",
#         "type": "город"
#       },
#       {
#         "name": "Свободы",
#         "type": "улица"
#       },
#       {
#         "number": "67",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# м. Теплый Станул. Профсоюзная, д.152, к. 2
# []
# Юридический адрес: 357600, Ставропольский край, г. Ессентуки, ул.
#                    -----------------------------------------------
# Семашко, 9
# ----------
# [
#   {
#     "parts": [
#       {
#         "value": "357600"
#       },
#       {
#         "name": "Ставропольский",
#         "type": "край"
#       },
#       {
#         "name": "Ессентуки",
#         "type": "город"
#       },
#       {
#         "name": "Семашко",
#         "type": "улица"
#       },
#       {
#         "number": "9"
#       }
#     ]
#   }
# ]
# ул. Г. Сибиряков, 2
# -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Г. Сибиряков",
#         "type": "улица"
#       },
#       {
#         "number": "2"
#       }
#     ]
#   }
# ]
# г. Севастополь, ул. Брестская, д. 18б, 299001
# -------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Севастополь",
#         "type": "город"
#       },
#       {
#         "name": "Брестская",
#         "type": "улица"
#       },
#       {
#         "number": "18б",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Адрес: 445008, г. Тольятти, ул. Громовой, 24
#        -------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "445008"
#       },
#       {
#         "name": "Тольятти",
#         "type": "город"
#       },
#       {
#         "name": "Громовой",
#         "type": "улица"
#       },
#       {
#         "number": "24"
#       }
#     ]
#   }
# ]
# 454091, г. Челябинск, Проспект Ленина, д.23Б, пом.2. каб 12
# --------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "454091"
#       },
#       {
#         "name": "Челябинск",
#         "type": "город"
#       },
#       {
#         "name": "Ленина",
#         "type": "проспект"
#       },
#       {
#         "number": "23Б",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Юридический адрес: Россия, 614036, г. Пермь, ул. Мира, 90, офис 7.
#                    ----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Россия"
#       },
#       {
#         "value": "614036"
#       },
#       {
#         "name": "Пермь",
#         "type": "город"
#       },
#       {
#         "name": "Мира",
#         "type": "улица"
#       },
#       {
#         "number": "90"
#       },
#       {
#         "number": "7",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Ялта, Алупкинское шоссе, д. 12а
#       -------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Алупкинское",
#         "type": "шоссе"
#       },
#       {
#         "number": "12а",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Новосибирская область, г.Искитим, ул.Пушкина, 40
# ------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Новосибирская",
#         "type": "область"
#       },
#       {
#         "name": "Искитим",
#         "type": "город"
#       },
#       {
#         "name": "Пушкина",
#         "type": "улица"
#       },
#       {
#         "number": "40"
#       }
#     ]
#   }
# ]
# г.Минусинск, пр.Кедровый 2
# --------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Минусинск",
#         "type": "город"
#       },
#       {
#         "name": "Кедровый",
#         "type": "проспект"
#       },
#       {
#         "number": "2"
#       }
#     ]
#   }
# ]
# 170026, г.Тверь, ул.Мусоргского, д.17
# -------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "170026"
#       },
#       {
#         "name": "Тверь",
#         "type": "город"
#       },
#       {
#         "name": "Мусоргского",
#         "type": "улица"
#       },
#       {
#         "number": "17",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 142900, Россия, Московская область, город Кашира, улица Стрелецкая,
# --------------------------------------------------------------------
# дом 70
# ------
# [
#   {
#     "parts": [
#       {
#         "value": "142900"
#       },
#       {
#         "name": "Россия"
#       },
#       {
#         "name": "Московская",
#         "type": "область"
#       },
#       {
#         "name": "Кашира",
#         "type": "город"
#       },
#       {
#         "name": "Стрелецкая",
#         "type": "улица"
#       },
#       {
#         "number": "70",
#         "type": "дом"
# ...
#         "value": "443022"
#       },
#       {
#         "name": "Самара",
#         "type": "город"
#       },
#       {
#         "name": "Заводское",
#         "type": "шоссе"
#       },
#       {
#         "number": "11"
#       },
#       {
#         "number": "418",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Кондитерское производство «АЛЬЯНС», Волгоградская обл. п.г.т.
#                                     --------------------------
# Городище, ул.Комунальная, 7
# ---------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Волгоградская",
#         "type": "область"
#       },
#       {
#         "name": "Городище",
#         "type": "посёлок"
#       },
#       {
#         "name": "Комунальная",
#         "type": "улица"
#       },
#       {
#         "number": "7"
#       }
#     ]
#   }
# ]
# Астра» на Тихорецком пр., д. 22/13 (Выборгский и
#           ------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Тихорецком",
#         "type": "проспект"
#       },
#       {
#         "number": "22/13",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 109044, г. Москва, ул. Динамовская д. 1а
# ----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "109044"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Динамовская",
#         "type": "улица"
#       },
#       {
#         "number": "1а",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ул. Интернациональная, д. 106  +7 (47545) 5-36-78  В будни: с 9 утра
# -----------------------------
# до 17 вечера
# [
#   {
#     "parts": [
#       {
#         "name": "Интернациональная",
#         "type": "улица"
#       },
#       {
#         "number": "106",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Москва, пл. Киевского вокзала, д. 2, ТРЦ Европейский, 7
# -----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Киевского вокзала",
#         "type": "площадь"
#       },
#       {
#         "number": "2",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 197373, г.Санкт-Петербург, ТЦ «ГОРИЗОНТ», Проспект Авиаконструкторов,
#                                           ----------------------------
# д. 2, оф. 312
# -------------
# [
#   {
#     "parts": [
#       {
#         "name": "Авиаконструкторов",
#         "type": "проспект"
#       },
#       {
#         "number": "2",
#         "type": "дом"
#       },
#       {
#         "number": "312",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# 1–этажное, общей площадью 77,50 кв.м., основная площадь 75,30 кв.м.,
#                                        -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "основная",
#         "type": "площадь"
#       },
#       {
#         "number": "75"
#       }
#     ]
#   }
# ]
# г. Старая Русса, ул. Кириллова, 16. Тел. (8-816-52) 5-70-58
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Старая Русса",
#         "type": "город"
#       },
#       {
#         "name": "Кириллова",
#         "type": "улица"
#       },
#       {
#         "number": "16"
#       }
#     ]
#   }
# ]
# к ул. Западная. Через 50 м. увидите стоянку у проходной 345"
# []
# г. Вологда, ул. Лаврова, д. 13
# ------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Вологда",
#         "type": "город"
#       },
#       {
#         "name": "Лаврова",
#         "type": "улица"
#       },
#       {
#         "number": "13",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Московское шоссе, д.12 офис 514
# -------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Московское",
#         "type": "шоссе"
#       },
#       {
#         "number": "12",
#         "type": "дом"
#       },
#       {
#         "number": "514",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г.Санкт-Петербург, пр. Большой Смоленский, д.10, оф. 315
# --------------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Санкт-Петербург",
#         "type": "город"
#       },
#       {
#         "name": "Большой Смоленский",
#         "type": "проспект"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       },
#       {
#         "number": "315",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# Россия, 150003, г. Ярославль, ул. Терешковой, д.14
# --------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Россия"
#       },
#       {
#         "value": "150003"
#       },
#       {
#         "name": "Ярославль",
#         "type": "город"
#       },
#       {
#         "name": "Терешковой",
#         "type": "улица"
#       },
#       {
#         "number": "14",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Комсомольский проспект, д. 13/1
# -------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Комсомольский",
#         "type": "проспект"
#       },
#       {
#         "number": "13/1",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# и социальному служению | Руководитель - диакон Максим Мухаметдинов |
# 660021, г. Красноярск, ул. Горького, 27, каб. 1-04, тел. (391)
# ---------------------------------------
# 227-73-90, vk.com
# [
#   {
#     "parts": [
#       {
#         "value": "660021"
#       },
#       {
#         "name": "Красноярск",
#         "type": "город"
#       },
#       {
#         "name": "Горького",
#         "type": "улица"
#       },
#       {
#         "number": "27"
#       }
#     ]
#   }
# ]
# г. Якутск, ул. Маяковского, д.84
# --------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Якутск",
#         "type": "город"
#       },
#       {
#         "name": "Маяковского",
#         "type": "улица"
#       },
#       {
#         "number": "84",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Зеленоград: пр-д 4806, д. 5, стр. 20
# []
# 150014, Ярославль, ул. Салтыкова – Щедрина 36/48
# ------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "150014"
#       },
#       {
#         "name": "Ярославль"
#       },
#       {
#         "name": "Салтыкова - Щедрина",
#         "type": "улица"
#       },
#       {
#         "number": "36/48"
#       }
#     ]
#   }
# ]
# г. Санкт-Петербург, ул. Большая Морская, д. 3-5, лит. А оф. 502,503
# -----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Санкт-Петербург",
#         "type": "город"
#       },
#       {
#         "name": "Большая Морская",
#         "type": "улица"
#       },
#       {
#         "number": "3-5",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 603000, г. Нижний Новгород, ул. Костина, д. 6/1, офис 2
# -------------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "603000"
#       },
#       {
#         "name": "Нижний Новгород",
#         "type": "город"
#       },
#       {
#         "name": "Костина",
#         "type": "улица"
#       },
#       {
#         "number": "6/1",
#         "type": "дом"
#       },
#       {
#         "number": "2",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г. Екатеринбург, ул. Луначарского, 81, оф. 803
# ----------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Екатеринбург",
#         "type": "город"
#       },
#       {
#         "name": "Луначарского",
#         "type": "улица"
#       },
#       {
#         "number": "81"
#       },
#       {
#         "number": "803",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г. Челябинск, ул.Сони Кривой, 83 офис 218
# -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Челябинск",
#         "type": "город"
#       },
#       {
#         "name": "Сони Кривой",
#         "type": "улица"
#       },
#       {
#         "number": "83"
#       },
#       {
#         "number": "218",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# г. Нижний Новгород, ул. Федосеенко, д. 47.
# -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Нижний Новгород",
#         "type": "город"
#       },
#       {
#         "name": "Федосеенко",
#         "type": "улица"
#       },
#       {
#         "number": "47",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Адрес: 115477, г. Москва ул. Кантемировская, вл. 64
# []
# 220007, г. Минск, ул. Жуковского, 4, офис 2  \+ 375 17 222 88 44
# -------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "220007"
#       },
#       {
#         "name": "Минск",
#         "type": "город"
#       },
#       {
#         "name": "Жуковского",
#         "type": "улица"
#       },
#       {
#         "number": "4"
#       },
#       {
#         "number": "2",
#         "type": "офис"
#       }
#     ]
#   }
# ]
# C) 196653 СПб, Колпино пр.Ленина, д.9/15
#                        -----------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ленина",
#         "type": "проспект"
#       },
#       {
#         "number": "9/15",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 1-й Дорожный проезд д.9
# -----------------------
# [
#   {
#     "parts": [
#       {
#         "name": "1-й Дорожный",
#         "type": "проезд"
#       },
#       {
#         "number": "9",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Адрес: Пулковское шоссе, д. 27А
#        ------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Пулковское",
#         "type": "шоссе"
#       },
#       {
#         "number": "27А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 123317, г.Москва, ул.Литвина-Седого, д.7А
# -----------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "123317"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Литвина-Седого",
#         "type": "улица"
#       },
#       {
#         "number": "7А",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Беговая г. Москва, Хорошевское шоссе, д. 1
#         ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Хорошевское",
#         "type": "шоссе"
#       },
#       {
#         "number": "1",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Москва Коровинское:125412, Коровинское шоссе, д. 35, стр.1
#                    ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "125412"
#       },
#       {
#         "name": "Коровинское",
#         "type": "шоссе"
#       },
#       {
#         "number": "35",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# г. Казань, ул. Карла Маркса, д. 46
# ----------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Казань",
#         "type": "город"
#       },
#       {
#         "name": "Карла Маркса",
#         "type": "улица"
#       },
#       {
#         "number": "46",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ул. Маковского д.22. офис 5..
# -------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Маковского",
#         "type": "улица"
#       },
#       {
#         "number": "22",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# ул. Авиамоторная, д.10, стр.2
# -----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Авиамоторная",
#         "type": "улица"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       },
#       {
#         "type": "строение"
#       }
#     ]
#   }
# ]
# г. Уфа, ш. Индустриальное, 44/1 г. Уфа, ш. Индустриальное, 44/1
# ------------------------------- -------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Уфа",
#         "type": "город"
#       },
#       {
#         "name": "Индустриальное",
#         "type": "шоссе"
#       },
#       {
#         "number": "44/1"
#       }
#     ]
#   },
#   {
#     "parts": [
#       {
#         "name": "Уфа",
#         "type": "город"
#       },
#       {
#         "name": "Индустриальное",
#         "type": "шоссе"
#       },
#       {
#         "number": "44/1"
#       }
#     ]
#   }
# ]
# 11» р.п. Голышманово , Объединенный филиал № 1 Омутинская ЦРБ, 627070
#                                                                -------
# Тюменская область, Омутинский р-н, с. Омутинское, ул. Луначарского,22
# ---------------------------------------------------------------------
# Сайт: http://ob16.my1
# [
#   {
#     "parts": [
#       {
#         "value": "627070"
#       },
#       {
#         "name": "Тюменская",
#         "type": "область"
#       },
#       {
#         "name": "Омутинский",
#         "type": "район"
#       },
#       {
#         "name": "Омутинское",
#         "type": "село"
#       },
#       {
#         "name": "Луначарского",
#         "type": "улица"
#       },
#       {
#         "number": "22"
#       }
#     ]
#   }
# ]
# 410031, г. Саратов, ул. Соборная, 42 (угол ул
# ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "410031"
#       },
#       {
#         "name": "Саратов",
#         "type": "город"
#       },
#       {
#         "name": "Соборная",
#         "type": "улица"
#       },
#       {
#         "number": "42"
#       }
#     ]
#   }
# ]
# 119021, Москва, ул.Тимура Фрунзе, д. 24
# ---------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "119021"
#       },
#       {
#         "name": "Москва"
#       },
#       {
#         "name": "Тимура Фрунзе",
#         "type": "улица"
#       },
#       {
#         "number": "24",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Женская консультация: 298609, РФ, РК, г. Ялта, ул. Халтурина, 11А;
#                                       ---------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Ялта",
#         "type": "город"
#       },
#       {
#         "name": "Халтурина",
#         "type": "улица"
#       },
#       {
#         "number": "11А"
#       }
#     ]
#   }
# ]
# доп. офис): 125124, г.Москва, ул.Ямского поля 1-я, д.17, корп.13
#             ----------------------------------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "125124"
#       },
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Ямского поля 1-я",
#         "type": "улица"
#       },
#       {
#         "number": "17",
#         "type": "дом"
#       },
#       {
#         "number": "13",
#         "type": "корпус"
#       }
#     ]
#   }
# ]
# г. Москва, Хользунова переулок, д.10 (м
# ------------------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Москва",
#         "type": "город"
#       },
#       {
#         "name": "Хользунова",
#         "type": "переулок"
#       },
#       {
#         "number": "10",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# Почтовый адрес Администрации Большелугского городского поселения:
# 666013, Иркутская область, Шелеховский район, р.п. Большой Луг, ул.
# --------------------------------------------------------------------
# 2-я Железнодорожная,  д.15
# --------------------------
# [
#   {
#     "parts": [
#       {
#         "value": "666013"
#       },
#       {
#         "name": "Иркутская",
#         "type": "область"
#       },
#       {
#         "name": "Шелеховский",
#         "type": "район"
#       },
#       {
#         "name": "Большой Луг",
#         "type": "посёлок"
#       },
#       {
#         "name": "2-я Железнодорожная",
#         "type": "улица"
#       },
#       {
#         "number": "15",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# 2. Россия,Краснодарский край, г. Краснодар, ул. Ставропольская, 213,
#    ----------------------------------------------------------------
# тел. 8(861)234-09-36
# [
#   {
#     "parts": [
#       {
#         "name": "Россия"
#       },
#       {
#         "name": "Краснодарский",
#         "type": "край"
#       },
#       {
#         "name": "Краснодар",
#         "type": "город"
#       },
#       {
#         "name": "Ставропольская",
#         "type": "улица"
#       },
#       {
#         "number": "213"
#       }
#     ]
#   }
# ]
# ул. Гагарина д.14а
# ------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Гагарина",
#         "type": "улица"
#       },
#       {
#         "number": "14а",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г.Кировск, ул. Победы, д. 38а
# -----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Кировск",
#         "type": "город"
#       },
#       {
#         "name": "Победы",
#         "type": "улица"
#       },
#       {
#         "number": "38а",
#         "type": "дом"
#       }
#     ]
#   }
# ]
# г. Карачев, ул. Ленина, 21-6 Тел. (48335) 2-48-74
# ----------------------------
# [
#   {
#     "parts": [
#       {
#         "name": "Карачев",
#         "type": "город"
#       },
#       {
#         "name": "Ленина",
#         "type": "улица"
#       },
#       {
#         "number": "21-6"
#       }
#     ]
#   }
# ]
